# %% [markdown]
# # 1. Data collection

# %% [markdown]
# ### Output/Deliverables:
# - For each exercise, a notebook in the folder notebooks/ must be commited
# - Create one reusable (shared across exercises) python function called paginate_api_calls that will handle the pagination of the API. - It will accept two arguments (url, parameters)
# - Create one reusable python function called write_json_file that will write the responses to disk
# - Exercise 1: One JSON file containing all teams in the folder /data/teams. Each row in this file will represent one API response. You can find an example in sample/data/teams.json
# - Exercise 2: One JSON file containing all games in the folder /data/games. Each row in this file will represent one API response. You can find an example in sample/data/games.json
# - Exercise 3: One JSON file containing all players in the folder /data/players. Each row in this file will represent one API response. You can find an example in sample/data/players.json
# - Pagination must be dynamic. i.e. control pagination until the end.
# - Git repository must not contain any JSON/CSV files
#
# ### Key Points:
# - Pagination. Each API call contains metadata that you can use to control it. I recommend to use the attribute next_page 'meta': {'total_pages': 2, 'current_page': 1, 'next_page': 2, 'per_page': 30, 'total_count': 45}
# - Reducing the number of API calls to the maximum. There is a parameter to increase the number of items retrieved in each API call. By modifying it, you can reduce the total number of API Calls
# - API Search/Query: Read the docs carefully

# %%
# request
# ==============================================================================
import requests

# Data processing
# ==============================================================================
import pandas as pd
import numpy as np
import json

#Allows us to display more than one output per cell
# ==============================================================================
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" 

# Display all columns
# ==============================================================================
pd.options.display.max_columns = None

# %% [markdown]
# `` Create one reusable (shared across exercises) python function called paginate_api_calls that will handle the pagination of the API. It will accept two arguments (url, parameters) ``

# %%
# The above code is creating a function that is going to be used to paginate the API calls.

def paginate_api_calls(url, params): # You must give the url and the params as a dictionary

    params.setdefault("page",1) #

 # To call the API

    response = requests.get(url, params)
    status_code = response.status_code
    reason_state = response.reason

    # To obtein information abour the status of the API call

    if status_code == 200:
        print('The request was successful, the status code was returned:',status_code,' and as reason for the status code:',reason_state)
    elif status_code == 402:
        print('User could not be authorised, status code returned:', status_code,' and as reason for the status code: ',reason_state)
    elif status_code == 404:
        print('Something went wrong, the resource was not found, the status code was returned:', status_code,' and as reason for the status code: ',reason_state)
    else:
        print('Something unexpected has happened, the status code has been returned:', status_code,' and as reason for the status code: ',reason_state)

    # For pagination, it will apply if the answer has metadata about pagination

    if "meta" in response.json().keys(): # The API call can contain metadata as meta or not, the case of season averages.

        meta = response.json()["meta"]
        results=[]

        # This is a while loop that is going to iterate through the pages of the API.
        while params["page"] != meta["next_page"]+1:

            response = requests.get(url,params)
            results.append(response.json())
            params["page"] += 1
        
        return results

    # This is a condition that is going to be used if the API call does not have metadata for pagination.
    else:
       
        print("There is not page parameter")
        results =response.json()

        return results

# %% [markdown]
# ``Create one reusable python function called write_json_file that will write the responses to disk``

# %%
# The above code is taking the results from the API call and writing them to a json file.
def write_json_file(results, name_of_file): # You must give the result of the API call and the ubi and name of the file that will be created as a string

    for i in results:

        if len(results) <= 1:
            print("There is only one page")

        else:
            call = json.dumps(i)
            with open(name_of_file+".json", "a") as outfile:
                outfile.write(call + "\n" )

    return "Se ha creado el archivo:", name_of_file+".json"

# %% [markdown]
# ## Exercise 1.1: Get all teams.
# - https://www.balldontlie.io/home.html#get-all-teams
# - Bear in mind pagination. It is possible to pass additional arguments to the API call.

# %%
# url and params to the API call
teams_url = 'https://www.balldontlie.io/api/v1/teams'
teams_params = {} # It must be a dictionary

# %%
# Function to the API call
teams = paginate_api_calls(teams_url, teams_params)
# Out:
# The request was successful, the status code was returned: 200  and as reason for the status code: OK

# %%
teams
# Out:
# [{'data': [{'id': 1,
#     'abbreviation': 'ATL',
#     'city': 'Atlanta',
#     'conference': 'East',
#     'division': 'Southeast',
#     'full_name': 'Atlanta Hawks',
#     'name': 'Hawks'},
#    {'id': 2,
#     'abbreviation': 'BOS',
#     'city': 'Boston',
#     'conference': 'East',
#     'division': 'Atlantic',
#     'full_name': 'Boston Celtics',
#     'name': 'Celtics'},
#    {'id': 3,
#     'abbreviation': 'BKN',
#     'city': 'Brooklyn',
#     'conference': 'East',
#     'division': 'Atlantic',
#     'full_name': 'Brooklyn Nets',
#     'name': 'Nets'},
#    {'id': 4,
#     'abbreviation': 'CHA',
#     'city': 'Charlotte',
#     'conference': 'East',
#     'division': 'Southeast',
#     'full_name': 'Charlotte Hornets',
#     'name': 'Hornets'},
#    {'id': 5,
#     'abbreviation': 'CHI',
#     'city': 'Chicago',
#     'conference': 'East',
#     'division': 'Central',
#     'full_name': 'Chicago Bulls',
#     'name': 'Bulls'},
#    {'id': 6,
#     'abbreviation': 'CLE',
#     'city': 'Cleveland',
#     'conference': 'East',
#     'division': 'Central',
#     'full_name': 'Cleveland Cavaliers',
#     'name': 'Cavaliers'},
#    {'id': 7,
#     'abbreviation': 'DAL',
#     'city': 'Dallas',
#     'conference': 'West',
#     'division': 'Southwest',
#     'full_name': 'Dallas Mavericks',
#     'name': 'Mavericks'},
#    {'id': 8,
#     'abbreviation': 'DEN',
#     'city': 'Denver',
#     'conference': 'West',
#     'division': 'Northwest',
#     'full_name': 'Denver Nuggets',
#     'name': 'Nuggets'},
#    {'id': 9,
#     'abbreviation': 'DET',
#     'city': 'Detroit',
#     'conference': 'East',
#     'division': 'Central',
#     'full_name': 'Detroit Pistons',
#     'name': 'Pistons'},
#    {'id': 10,
#     'abbreviation': 'GSW',
#     'city': 'Golden State',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'Golden State Warriors',
#     'name': 'Warriors'},
#    {'id': 11,
#     'abbreviation': 'HOU',
#     'city': 'Houston',
#     'conference': 'West',
#     'division': 'Southwest',
#     'full_name': 'Houston Rockets',
#     'name': 'Rockets'},
#    {'id': 12,
#     'abbreviation': 'IND',
#     'city': 'Indiana',
#     'conference': 'East',
#     'division': 'Central',
#     'full_name': 'Indiana Pacers',
#     'name': 'Pacers'},
#    {'id': 13,
#     'abbreviation': 'LAC',
#     'city': 'LA',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'LA Clippers',
#     'name': 'Clippers'},
#    {'id': 14,
#     'abbreviation': 'LAL',
#     'city': 'Los Angeles',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'Los Angeles Lakers',
#     'name': 'Lakers'},
#    {'id': 15,
#     'abbreviation': 'MEM',
#     'city': 'Memphis',
#     'conference': 'West',
#     'division': 'Southwest',
#     'full_name': 'Memphis Grizzlies',
#     'name': 'Grizzlies'},
#    {'id': 16,
#     'abbreviation': 'MIA',
#     'city': 'Miami',
#     'conference': 'East',
#     'division': 'Southeast',
#     'full_name': 'Miami Heat',
#     'name': 'Heat'},
#    {'id': 17,
#     'abbreviation': 'MIL',
#     'city': 'Milwaukee',
#     'conference': 'East',
#     'division': 'Central',
#     'full_name': 'Milwaukee Bucks',
#     'name': 'Bucks'},
#    {'id': 18,
#     'abbreviation': 'MIN',
#     'city': 'Minnesota',
#     'conference': 'West',
#     'division': 'Northwest',
#     'full_name': 'Minnesota Timberwolves',
#     'name': 'Timberwolves'},
#    {'id': 19,
#     'abbreviation': 'NOP',
#     'city': 'New Orleans',
#     'conference': 'West',
#     'division': 'Southwest',
#     'full_name': 'New Orleans Pelicans',
#     'name': 'Pelicans'},
#    {'id': 20,
#     'abbreviation': 'NYK',
#     'city': 'New York',
#     'conference': 'East',
#     'division': 'Atlantic',
#     'full_name': 'New York Knicks',
#     'name': 'Knicks'},
#    {'id': 21,
#     'abbreviation': 'OKC',
#     'city': 'Oklahoma City',
#     'conference': 'West',
#     'division': 'Northwest',
#     'full_name': 'Oklahoma City Thunder',
#     'name': 'Thunder'},
#    {'id': 22,
#     'abbreviation': 'ORL',
#     'city': 'Orlando',
#     'conference': 'East',
#     'division': 'Southeast',
#     'full_name': 'Orlando Magic',
#     'name': 'Magic'},
#    {'id': 23,
#     'abbreviation': 'PHI',
#     'city': 'Philadelphia',
#     'conference': 'East',
#     'division': 'Atlantic',
#     'full_name': 'Philadelphia 76ers',
#     'name': '76ers'},
#    {'id': 24,
#     'abbreviation': 'PHX',
#     'city': 'Phoenix',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'Phoenix Suns',
#     'name': 'Suns'},
#    {'id': 25,
#     'abbreviation': 'POR',
#     'city': 'Portland',
#     'conference': 'West',
#     'division': 'Northwest',
#     'full_name': 'Portland Trail Blazers',
#     'name': 'Trail Blazers'},
#    {'id': 26,
#     'abbreviation': 'SAC',
#     'city': 'Sacramento',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'Sacramento Kings',
#     'name': 'Kings'},
#    {'id': 27,
#     'abbreviation': 'SAS',
#     'city': 'San Antonio',
#     'conference': 'West',
#     'division': 'Southwest',
#     'full_name': 'San Antonio Spurs',
#     'name': 'Spurs'},
#    {'id': 28,
#     'abbreviation': 'TOR',
#     'city': 'Toronto',
#     'conference': 'East',
#     'division': 'Atlantic',
#     'full_name': 'Toronto Raptors',
#     'name': 'Raptors'},
#    {'id': 29,
#     'abbreviation': 'UTA',
#     'city': 'Utah',
#     'conference': 'West',
#     'division': 'Northwest',
#     'full_name': 'Utah Jazz',
#     'name': 'Jazz'},
#    {'id': 30,
#     'abbreviation': 'WAS',
#     'city': 'Washington',
#     'conference': 'East',
#     'division': 'Southeast',
#     'full_name': 'Washington Wizards',
#     'name': 'Wizards'}],
#   'meta': {'total_pages': 2,
#    'current_page': 1,
#    'next_page': 2,
#    'per_page': 30,
#    'total_count': 45}},
#  {'data': [{'id': 37,
#     'abbreviation': 'CHS',
#     'city': '',
#     'conference': '    ',
#     'division': '',
#     'full_name': 'Chicago Stags',
#     'name': 'Chicago Stags'},
#    {'id': 38,
#     'abbreviation': 'BOM',
#     'city': '',
#     'conference': '    ',
#     'division': '',
#     'full_name': 'St. Louis Bombers',
#     'name': 'St. Louis Bombers'},
#    {'id': 39,
#     'abbreviation': 'CLR',
#     'city': '',
#     'conference': '    ',
#     'division': '',
#     'full_name': 'Cleveland Rebels',
#     'name': 'Cleveland Rebels'},
#    {'id': 40,
#     'abbreviation': 'DEF',
#     'city': '',
#     'conference': '    ',
#     'division': '',
#     'full_name': 'Detroit Falcons',
#     'name': 'Detroit Falcons'},
#    {'id': 41,
#     'abbreviation': 'HUS',
#     'city': '',
#     'conference': '    ',
#     'division': '',
#     'full_name': 'Toronto Huskies',
#     'name': 'Toronto Huskies'},
#    {'id': 42,
#     'abbreviation': 'WAS',
#     'city': '',
#     'conference': '    ',
#     'division': '',
#     'full_name': 'Washington Capitols',
#     'name': 'Washington Capitols'},
#    {'id': 43,
#     'abbreviation': 'PRO',
#     'city': '',
#     'conference': '    ',
#     'division': '',
#     'full_name': 'Providence Steamrollers',
#     'name': 'Providence Steamrollers'},
#    {'id': 44,
#     'abbreviation': 'PIT',
#     'city': '',
#     'conference': '    ',
#     'division': '',
#     'full_name': 'Pittsburgh Ironmen',
#     'name': 'Pittsburgh Ironmen'},
#    {'id': 45,
#     'abbreviation': 'BAL',
#     'city': '',
#     'conference': '    ',
#     'division': '',
#     'full_name': 'Baltimore Bullets',
#     'name': 'Baltimore Bullets'},
#    {'id': 46,
#     'abbreviation': 'JET',
#     'city': '',
#     'conference': '    ',
#     'division': '',
#     'full_name': 'Indianapolis Jets',
#     'name': 'Indianapolis Jets'},
#    {'id': 47,
#     'abbreviation': 'AND',
#     'city': '',
#     'conference': '    ',
#     'division': '',
#     'full_name': 'Anderson Packers',
#     'name': 'Anderson Packers'},
#    {'id': 48,
#     'abbreviation': 'WAT',
#     'city': '',
#     'conference': '    ',
#     'division': '',
#     'full_name': 'Waterloo Hawks',
#     'name': 'Waterloo Hawks'},
#    {'id': 49,
#     'abbreviation': 'INO',
#     'city': '',
#     'conference': '    ',
#     'division': '',
#     'full_name': 'Indianapolis Olympians',
#     'name': 'Indianapolis Olympians'},
#    {'id': 50,
#     'abbreviation': 'DN',
#     'city': '',
#     'conference': '    ',
#     'division': '',
#     'full_name': 'Denver Nuggets',
#     'name': 'Denver Nuggets'},
#    {'id': 51,
#     'abbreviation': 'SHE',
#     'city': '',
#     'conference': '    ',
#     'division': '',
#     'full_name': 'Sheboygan Redskins',
#     'name': 'Sheboygan Redskins'}],
#   'meta': {'total_pages': 2,
#    'current_page': 2,
#    'next_page': None,
#    'per_page': 30,
#    'total_count': 45}}]

# %%
all_teams = write_json_file(teams,"notebooks/teams")

# %%
all_teams
# Out:
# ('Se ha creado el archivo:', 'notebooks/teams.json')

# %%
len(all_teams)
# Out:
# 2

# %% [markdown]
# ## Exercise 1.2
# - It is required to obtain all games of the 1991-1992 season. No need to rename/remove fields from the response.

# %%
# url and params to the API call
games_url = 'https://www.balldontlie.io/api/v1/games'
games_params= {'seasons[]': 1991, "per_page":100} # It must be a dictionary

# %%
# Function to the API call
games = paginate_api_calls(games_url, games_params)
# Out:
# The request was successful, the status code was returned: 200  and as reason for the status code: OK

# %%
games
# Out:
# [{'data': [{'id': 1164,
#     'date': '1991-11-08T00:00:00.000Z',
#     'home_team': {'id': 27,
#      'abbreviation': 'SAS',
#      'city': 'San Antonio',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'San Antonio Spurs',
#      'name': 'Spurs'},
#     'home_team_score': 107,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 6,
#      'abbreviation': 'CLE',
#      'city': 'Cleveland',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Cleveland Cavaliers',
#      'name': 'Cavaliers'},
#     'visitor_team_score': 101},
#    {'id': 1165,
#     'date': '1991-11-09T00:00:00.000Z',
#     'home_team': {'id': 21,
#      'abbreviation': 'OKC',
#      'city': 'Oklahoma City',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Oklahoma City Thunder',
#      'name': 'Thunder'},
#     'home_team_score': 118,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 12,
#      'abbreviation': 'IND',
#      'city': 'Indiana',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Indiana Pacers',
#      'name': 'Pacers'},
#     'visitor_team_score': 111},
#    {'id': 1166,
#     'date': '1992-04-15T00:00:00.000Z',
#     'home_team': {'id': 1,
#      'abbreviation': 'ATL',
#      'city': 'Atlanta',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Atlanta Hawks',
#      'name': 'Hawks'},
#     'home_team_score': 95,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 20,
#      'abbreviation': 'NYK',
#      'city': 'New York',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'New York Knicks',
#      'name': 'Knicks'},
#     'visitor_team_score': 94},
#    {'id': 1167,
#     'date': '1992-04-16T00:00:00.000Z',
#     'home_team': {'id': 13,
#      'abbreviation': 'LAC',
#      'city': 'LA',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'LA Clippers',
#      'name': 'Clippers'},
#     'home_team_score': 96,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 18,
#      'abbreviation': 'MIN',
#      'city': 'Minnesota',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Minnesota Timberwolves',
#      'name': 'Timberwolves'},
#     'visitor_team_score': 93},
#    {'id': 1168,
#     'date': '1992-04-17T00:00:00.000Z',
#     'home_team': {'id': 21,
#      'abbreviation': 'OKC',
#      'city': 'Oklahoma City',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Oklahoma City Thunder',
#      'name': 'Thunder'},
#     'home_team_score': 130,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 26,
#      'abbreviation': 'SAC',
#      'city': 'Sacramento',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Sacramento Kings',
#      'name': 'Kings'},
#     'visitor_team_score': 106},
#    {'id': 1169,
#     'date': '1992-04-19T00:00:00.000Z',
#     'home_team': {'id': 6,
#      'abbreviation': 'CLE',
#      'city': 'Cleveland',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Cleveland Cavaliers',
#      'name': 'Cavaliers'},
#     'home_team_score': 112,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 1,
#      'abbreviation': 'ATL',
#      'city': 'Atlanta',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Atlanta Hawks',
#      'name': 'Hawks'},
#     'visitor_team_score': 108},
#    {'id': 1300,
#     'date': '1991-11-08T00:00:00.000Z',
#     'home_team': {'id': 25,
#      'abbreviation': 'POR',
#      'city': 'Portland',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Portland Trail Blazers',
#      'name': 'Trail Blazers'},
#     'home_team_score': 121,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 12,
#      'abbreviation': 'IND',
#      'city': 'Indiana',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Indiana Pacers',
#      'name': 'Pacers'},
#     'visitor_team_score': 96},
#    {'id': 1301,
#     'date': '1991-11-09T00:00:00.000Z',
#     'home_team': {'id': 29,
#      'abbreviation': 'UTA',
#      'city': 'Utah',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Utah Jazz',
#      'name': 'Jazz'},
#     'home_team_score': 99,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 13,
#      'abbreviation': 'LAC',
#      'city': 'LA',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'LA Clippers',
#      'name': 'Clippers'},
#     'visitor_team_score': 84},
#    {'id': 1302,
#     'date': '1991-11-12T00:00:00.000Z',
#     'home_team': {'id': 26,
#      'abbreviation': 'SAC',
#      'city': 'Sacramento',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Sacramento Kings',
#      'name': 'Kings'},
#     'home_team_score': 103,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 2,
#      'abbreviation': 'BOS',
#      'city': 'Boston',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Boston Celtics',
#      'name': 'Celtics'},
#     'visitor_team_score': 126},
#    {'id': 1303,
#     'date': '1991-11-13T00:00:00.000Z',
#     'home_team': {'id': 16,
#      'abbreviation': 'MIA',
#      'city': 'Miami',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Miami Heat',
#      'name': 'Heat'},
#     'home_team_score': 107,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 9,
#      'abbreviation': 'DET',
#      'city': 'Detroit',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Detroit Pistons',
#      'name': 'Pistons'},
#     'visitor_team_score': 102},
#    {'id': 1304,
#     'date': '1991-11-14T00:00:00.000Z',
#     'home_team': {'id': 7,
#      'abbreviation': 'DAL',
#      'city': 'Dallas',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Dallas Mavericks',
#      'name': 'Mavericks'},
#     'home_team_score': 95,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 13,
#      'abbreviation': 'LAC',
#      'city': 'LA',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'LA Clippers',
#      'name': 'Clippers'},
#     'visitor_team_score': 88},
#    {'id': 1305,
#     'date': '1991-11-15T00:00:00.000Z',
#     'home_team': {'id': 14,
#      'abbreviation': 'LAL',
#      'city': 'Los Angeles',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Los Angeles Lakers',
#      'name': 'Lakers'},
#     'home_team_score': 86,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 11,
#      'abbreviation': 'HOU',
#      'city': 'Houston',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Houston Rockets',
#      'name': 'Rockets'},
#     'visitor_team_score': 74},
#    {'id': 1306,
#     'date': '1991-11-16T00:00:00.000Z',
#     'home_team': {'id': 4,
#      'abbreviation': 'CHA',
#      'city': 'Charlotte',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Charlotte Hornets',
#      'name': 'Hornets'},
#     'home_team_score': 118,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 2,
#      'abbreviation': 'BOS',
#      'city': 'Boston',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Boston Celtics',
#      'name': 'Celtics'},
#     'visitor_team_score': 109},
#    {'id': 1307,
#     'date': '1991-11-19T00:00:00.000Z',
#     'home_team': {'id': 3,
#      'abbreviation': 'BKN',
#      'city': 'Brooklyn',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Brooklyn Nets',
#      'name': 'Nets'},
#     'home_team_score': 122,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 26,
#      'abbreviation': 'SAC',
#      'city': 'Sacramento',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Sacramento Kings',
#      'name': 'Kings'},
#     'visitor_team_score': 118},
#    {'id': 1308,
#     'date': '1991-11-20T00:00:00.000Z',
#     'home_team': {'id': 23,
#      'abbreviation': 'PHI',
#      'city': 'Philadelphia',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Philadelphia 76ers',
#      'name': '76ers'},
#     'home_team_score': 114,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 16,
#      'abbreviation': 'MIA',
#      'city': 'Miami',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Miami Heat',
#      'name': 'Heat'},
#     'visitor_team_score': 107},
#    {'id': 1309,
#     'date': '1991-11-22T00:00:00.000Z',
#     'home_team': {'id': 16,
#      'abbreviation': 'MIA',
#      'city': 'Miami',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Miami Heat',
#      'name': 'Heat'},
#     'home_team_score': 118,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 26,
#      'abbreviation': 'SAC',
#      'city': 'Sacramento',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Sacramento Kings',
#      'name': 'Kings'},
#     'visitor_team_score': 112},
#    {'id': 1310,
#     'date': '1991-11-23T00:00:00.000Z',
#     'home_team': {'id': 12,
#      'abbreviation': 'IND',
#      'city': 'Indiana',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Indiana Pacers',
#      'name': 'Pacers'},
#     'home_team_score': 119,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 16,
#      'abbreviation': 'MIA',
#      'city': 'Miami',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Miami Heat',
#      'name': 'Heat'},
#     'visitor_team_score': 83},
#    {'id': 1311,
#     'date': '1991-11-24T00:00:00.000Z',
#     'home_team': {'id': 14,
#      'abbreviation': 'LAL',
#      'city': 'Los Angeles',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Los Angeles Lakers',
#      'name': 'Lakers'},
#     'home_team_score': 102,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 17,
#      'abbreviation': 'MIL',
#      'city': 'Milwaukee',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Milwaukee Bucks',
#      'name': 'Bucks'},
#     'visitor_team_score': 97},
#    {'id': 1312,
#     'date': '1991-11-26T00:00:00.000Z',
#     'home_team': {'id': 11,
#      'abbreviation': 'HOU',
#      'city': 'Houston',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Houston Rockets',
#      'name': 'Rockets'},
#     'home_team_score': 118,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 3,
#      'abbreviation': 'BKN',
#      'city': 'Brooklyn',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Brooklyn Nets',
#      'name': 'Nets'},
#     'visitor_team_score': 109},
#    {'id': 1313,
#     'date': '1991-11-27T00:00:00.000Z',
#     'home_team': {'id': 18,
#      'abbreviation': 'MIN',
#      'city': 'Minnesota',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Minnesota Timberwolves',
#      'name': 'Timberwolves'},
#     'home_team_score': 101,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 8,
#      'abbreviation': 'DEN',
#      'city': 'Denver',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Denver Nuggets',
#      'name': 'Nuggets'},
#     'visitor_team_score': 92},
#    {'id': 1314,
#     'date': '1991-11-29T00:00:00.000Z',
#     'home_team': {'id': 29,
#      'abbreviation': 'UTA',
#      'city': 'Utah',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Utah Jazz',
#      'name': 'Jazz'},
#     'home_team_score': 133,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 10,
#      'abbreviation': 'GSW',
#      'city': 'Golden State',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Golden State Warriors',
#      'name': 'Warriors'},
#     'visitor_team_score': 108},
#    {'id': 1315,
#     'date': '1991-11-30T00:00:00.000Z',
#     'home_team': {'id': 7,
#      'abbreviation': 'DAL',
#      'city': 'Dallas',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Dallas Mavericks',
#      'name': 'Mavericks'},
#     'home_team_score': 79,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 18,
#      'abbreviation': 'MIN',
#      'city': 'Minnesota',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Minnesota Timberwolves',
#      'name': 'Timberwolves'},
#     'visitor_team_score': 78},
#    {'id': 1316,
#     'date': '1991-12-03T00:00:00.000Z',
#     'home_team': {'id': 7,
#      'abbreviation': 'DAL',
#      'city': 'Dallas',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Dallas Mavericks',
#      'name': 'Mavericks'},
#     'home_team_score': 99,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 1,
#      'abbreviation': 'ATL',
#      'city': 'Atlanta',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Atlanta Hawks',
#      'name': 'Hawks'},
#     'visitor_team_score': 103},
#    {'id': 1317,
#     'date': '1991-12-04T00:00:00.000Z',
#     'home_team': {'id': 4,
#      'abbreviation': 'CHA',
#      'city': 'Charlotte',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Charlotte Hornets',
#      'name': 'Hornets'},
#     'home_team_score': 124,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 14,
#      'abbreviation': 'LAL',
#      'city': 'Los Angeles',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Los Angeles Lakers',
#      'name': 'Lakers'},
#     'visitor_team_score': 106},
#    {'id': 1318,
#     'date': '1991-12-05T00:00:00.000Z',
#     'home_team': {'id': 17,
#      'abbreviation': 'MIL',
#      'city': 'Milwaukee',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Milwaukee Bucks',
#      'name': 'Bucks'},
#     'home_team_score': 101,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 3,
#      'abbreviation': 'BKN',
#      'city': 'Brooklyn',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Brooklyn Nets',
#      'name': 'Nets'},
#     'visitor_team_score': 109},
#    {'id': 1319,
#     'date': '1991-12-06T00:00:00.000Z',
#     'home_team': {'id': 23,
#      'abbreviation': 'PHI',
#      'city': 'Philadelphia',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Philadelphia 76ers',
#      'name': '76ers'},
#     'home_team_score': 105,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 25,
#      'abbreviation': 'POR',
#      'city': 'Portland',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Portland Trail Blazers',
#      'name': 'Trail Blazers'},
#     'visitor_team_score': 102},
#    {'id': 1320,
#     'date': '1991-12-07T00:00:00.000Z',
#     'home_team': {'id': 10,
#      'abbreviation': 'GSW',
#      'city': 'Golden State',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Golden State Warriors',
#      'name': 'Warriors'},
#     'home_team_score': 124,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 26,
#      'abbreviation': 'SAC',
#      'city': 'Sacramento',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Sacramento Kings',
#      'name': 'Kings'},
#     'visitor_team_score': 120},
#    {'id': 1321,
#     'date': '1991-12-10T00:00:00.000Z',
#     'home_team': {'id': 26,
#      'abbreviation': 'SAC',
#      'city': 'Sacramento',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Sacramento Kings',
#      'name': 'Kings'},
#     'home_team_score': 90,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 14,
#      'abbreviation': 'LAL',
#      'city': 'Los Angeles',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Los Angeles Lakers',
#      'name': 'Lakers'},
#     'visitor_team_score': 92},
#    {'id': 1322,
#     'date': '1991-12-11T00:00:00.000Z',
#     'home_team': {'id': 13,
#      'abbreviation': 'LAC',
#      'city': 'LA',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'LA Clippers',
#      'name': 'Clippers'},
#     'home_team_score': 101,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 9,
#      'abbreviation': 'DET',
#      'city': 'Detroit',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Detroit Pistons',
#      'name': 'Pistons'},
#     'visitor_team_score': 96},
#    {'id': 1323,
#     'date': '1991-12-13T00:00:00.000Z',
#     'home_team': {'id': 13,
#      'abbreviation': 'LAC',
#      'city': 'LA',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'LA Clippers',
#      'name': 'Clippers'},
#     'home_team_score': 102,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 29,
#      'abbreviation': 'UTA',
#      'city': 'Utah',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Utah Jazz',
#      'name': 'Jazz'},
#     'visitor_team_score': 101},
#    {'id': 1324,
#     'date': '1991-12-14T00:00:00.000Z',
#     'home_team': {'id': 11,
#      'abbreviation': 'HOU',
#      'city': 'Houston',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Houston Rockets',
#      'name': 'Rockets'},
#     'home_team_score': 100,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 27,
#      'abbreviation': 'SAS',
#      'city': 'San Antonio',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'San Antonio Spurs',
#      'name': 'Spurs'},
#     'visitor_team_score': 107},
#    {'id': 1325,
#     'date': '1991-12-14T00:00:00.000Z',
#     'home_team': {'id': 16,
#      'abbreviation': 'MIA',
#      'city': 'Miami',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Miami Heat',
#      'name': 'Heat'},
#     'home_team_score': 121,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 1,
#      'abbreviation': 'ATL',
#      'city': 'Atlanta',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Atlanta Hawks',
#      'name': 'Hawks'},
#     'visitor_team_score': 101},
#    {'id': 1326,
#     'date': '1991-12-15T00:00:00.000Z',
#     'home_team': {'id': 13,
#      'abbreviation': 'LAC',
#      'city': 'LA',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'LA Clippers',
#      'name': 'Clippers'},
#     'home_team_score': 119,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 22,
#      'abbreviation': 'ORL',
#      'city': 'Orlando',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Orlando Magic',
#      'name': 'Magic'},
#     'visitor_team_score': 104},
#    {'id': 1327,
#     'date': '1991-12-16T00:00:00.000Z',
#     'home_team': {'id': 25,
#      'abbreviation': 'POR',
#      'city': 'Portland',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Portland Trail Blazers',
#      'name': 'Trail Blazers'},
#     'home_team_score': 119,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 18,
#      'abbreviation': 'MIN',
#      'city': 'Minnesota',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Minnesota Timberwolves',
#      'name': 'Timberwolves'},
#     'visitor_team_score': 104},
#    {'id': 1328,
#     'date': '1992-04-15T00:00:00.000Z',
#     'home_team': {'id': 29,
#      'abbreviation': 'UTA',
#      'city': 'Utah',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Utah Jazz',
#      'name': 'Jazz'},
#     'home_team_score': 130,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 11,
#      'abbreviation': 'HOU',
#      'city': 'Houston',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Houston Rockets',
#      'name': 'Rockets'},
#     'visitor_team_score': 98},
#    {'id': 1329,
#     'date': '1992-04-16T00:00:00.000Z',
#     'home_team': {'id': 26,
#      'abbreviation': 'SAC',
#      'city': 'Sacramento',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Sacramento Kings',
#      'name': 'Kings'},
#     'home_team_score': 102,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 14,
#      'abbreviation': 'LAL',
#      'city': 'Los Angeles',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Los Angeles Lakers',
#      'name': 'Lakers'},
#     'visitor_team_score': 94},
#    {'id': 1330,
#     'date': '1992-04-17T00:00:00.000Z',
#     'home_team': {'id': 27,
#      'abbreviation': 'SAS',
#      'city': 'San Antonio',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'San Antonio Spurs',
#      'name': 'Spurs'},
#     'home_team_score': 108,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 8,
#      'abbreviation': 'DEN',
#      'city': 'Denver',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Denver Nuggets',
#      'name': 'Nuggets'},
#     'visitor_team_score': 94},
#    {'id': 1331,
#     'date': '1992-04-19T00:00:00.000Z',
#     'home_team': {'id': 10,
#      'abbreviation': 'GSW',
#      'city': 'Golden State',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Golden State Warriors',
#      'name': 'Warriors'},
#     'home_team_score': 108,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 21,
#      'abbreviation': 'OKC',
#      'city': 'Oklahoma City',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Oklahoma City Thunder',
#      'name': 'Thunder'},
#     'visitor_team_score': 106},
#    {'id': 1441,
#     'date': '1991-11-08T00:00:00.000Z',
#     'home_team': {'id': 2,
#      'abbreviation': 'BOS',
#      'city': 'Boston',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Boston Celtics',
#      'name': 'Celtics'},
#     'home_team_score': 95,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 1,
#      'abbreviation': 'ATL',
#      'city': 'Atlanta',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Atlanta Hawks',
#      'name': 'Hawks'},
#     'visitor_team_score': 100},
#    {'id': 1442,
#     'date': '1991-11-09T00:00:00.000Z',
#     'home_team': {'id': 1,
#      'abbreviation': 'ATL',
#      'city': 'Atlanta',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Atlanta Hawks',
#      'name': 'Hawks'},
#     'home_team_score': 97,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 16,
#      'abbreviation': 'MIA',
#      'city': 'Miami',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Miami Heat',
#      'name': 'Heat'},
#     'visitor_team_score': 93},
#    {'id': 1443,
#     'date': '1991-11-12T00:00:00.000Z',
#     'home_team': {'id': 1,
#      'abbreviation': 'ATL',
#      'city': 'Atlanta',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Atlanta Hawks',
#      'name': 'Hawks'},
#     'home_team_score': 118,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 4,
#      'abbreviation': 'CHA',
#      'city': 'Charlotte',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Charlotte Hornets',
#      'name': 'Hornets'},
#     'visitor_team_score': 100},
#    {'id': 1444,
#     'date': '1991-11-13T00:00:00.000Z',
#     'home_team': {'id': 4,
#      'abbreviation': 'CHA',
#      'city': 'Charlotte',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Charlotte Hornets',
#      'name': 'Hornets'},
#     'home_team_score': 95,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 5,
#      'abbreviation': 'CHI',
#      'city': 'Chicago',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Chicago Bulls',
#      'name': 'Bulls'},
#     'visitor_team_score': 117},
#    {'id': 1445,
#     'date': '1991-11-14T00:00:00.000Z',
#     'home_team': {'id': 10,
#      'abbreviation': 'GSW',
#      'city': 'Golden State',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Golden State Warriors',
#      'name': 'Warriors'},
#     'home_team_score': 112,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 14,
#      'abbreviation': 'LAL',
#      'city': 'Los Angeles',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Los Angeles Lakers',
#      'name': 'Lakers'},
#     'visitor_team_score': 115},
#    {'id': 1446,
#     'date': '1991-11-15T00:00:00.000Z',
#     'home_team': {'id': 24,
#      'abbreviation': 'PHX',
#      'city': 'Phoenix',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Phoenix Suns',
#      'name': 'Suns'},
#     'home_team_score': 115,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 1,
#      'abbreviation': 'ATL',
#      'city': 'Atlanta',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Atlanta Hawks',
#      'name': 'Hawks'},
#     'visitor_team_score': 119},
#    {'id': 1447,
#     'date': '1991-11-16T00:00:00.000Z',
#     'home_team': {'id': 30,
#      'abbreviation': 'WAS',
#      'city': 'Washington',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Washington Wizards',
#      'name': 'Wizards'},
#     'home_team_score': 98,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 29,
#      'abbreviation': 'UTA',
#      'city': 'Utah',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Utah Jazz',
#      'name': 'Jazz'},
#     'visitor_team_score': 107},
#    {'id': 1448,
#     'date': '1991-11-19T00:00:00.000Z',
#     'home_team': {'id': 30,
#      'abbreviation': 'WAS',
#      'city': 'Washington',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Washington Wizards',
#      'name': 'Wizards'},
#     'home_team_score': 106,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 21,
#      'abbreviation': 'OKC',
#      'city': 'Oklahoma City',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Oklahoma City Thunder',
#      'name': 'Thunder'},
#     'visitor_team_score': 113},
#    {'id': 1449,
#     'date': '1991-11-20T00:00:00.000Z',
#     'home_team': {'id': 9,
#      'abbreviation': 'DET',
#      'city': 'Detroit',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Detroit Pistons',
#      'name': 'Pistons'},
#     'home_team_score': 86,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 21,
#      'abbreviation': 'OKC',
#      'city': 'Oklahoma City',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Oklahoma City Thunder',
#      'name': 'Thunder'},
#     'visitor_team_score': 91},
#    {'id': 1450,
#     'date': '1991-11-21T00:00:00.000Z',
#     'home_team': {'id': 6,
#      'abbreviation': 'CLE',
#      'city': 'Cleveland',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Cleveland Cavaliers',
#      'name': 'Cavaliers'},
#     'home_team_score': 116,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 3,
#      'abbreviation': 'BKN',
#      'city': 'Brooklyn',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Brooklyn Nets',
#      'name': 'Nets'},
#     'visitor_team_score': 112},
#    {'id': 1451,
#     'date': '1991-11-22T00:00:00.000Z',
#     'home_team': {'id': 21,
#      'abbreviation': 'OKC',
#      'city': 'Oklahoma City',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Oklahoma City Thunder',
#      'name': 'Thunder'},
#     'home_team_score': 109,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 5,
#      'abbreviation': 'CHI',
#      'city': 'Chicago',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Chicago Bulls',
#      'name': 'Bulls'},
#     'visitor_team_score': 112},
#    {'id': 1452,
#     'date': '1991-11-23T00:00:00.000Z',
#     'home_team': {'id': 10,
#      'abbreviation': 'GSW',
#      'city': 'Golden State',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Golden State Warriors',
#      'name': 'Warriors'},
#     'home_team_score': 120,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 17,
#      'abbreviation': 'MIL',
#      'city': 'Milwaukee',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Milwaukee Bucks',
#      'name': 'Bucks'},
#     'visitor_team_score': 115},
#    {'id': 1453,
#     'date': '1991-11-26T00:00:00.000Z',
#     'home_team': {'id': 25,
#      'abbreviation': 'POR',
#      'city': 'Portland',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Portland Trail Blazers',
#      'name': 'Trail Blazers'},
#     'home_team_score': 107,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 17,
#      'abbreviation': 'MIL',
#      'city': 'Milwaukee',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Milwaukee Bucks',
#      'name': 'Bucks'},
#     'visitor_team_score': 98},
#    {'id': 1454,
#     'date': '1991-11-27T00:00:00.000Z',
#     'home_team': {'id': 29,
#      'abbreviation': 'UTA',
#      'city': 'Utah',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Utah Jazz',
#      'name': 'Jazz'},
#     'home_team_score': 113,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 4,
#      'abbreviation': 'CHA',
#      'city': 'Charlotte',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Charlotte Hornets',
#      'name': 'Hornets'},
#     'visitor_team_score': 107},
#    {'id': 1455,
#     'date': '1991-11-29T00:00:00.000Z',
#     'home_team': {'id': 2,
#      'abbreviation': 'BOS',
#      'city': 'Boston',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Boston Celtics',
#      'name': 'Celtics'},
#     'home_team_score': 114,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 14,
#      'abbreviation': 'LAL',
#      'city': 'Los Angeles',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Los Angeles Lakers',
#      'name': 'Lakers'},
#     'visitor_team_score': 91},
#    {'id': 1456,
#     'date': '1991-11-30T00:00:00.000Z',
#     'home_team': {'id': 13,
#      'abbreviation': 'LAC',
#      'city': 'LA',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'LA Clippers',
#      'name': 'Clippers'},
#     'home_team_score': 130,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 4,
#      'abbreviation': 'CHA',
#      'city': 'Charlotte',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Charlotte Hornets',
#      'name': 'Hornets'},
#     'visitor_team_score': 112},
#    {'id': 1457,
#     'date': '1991-12-03T00:00:00.000Z',
#     'home_team': {'id': 16,
#      'abbreviation': 'MIA',
#      'city': 'Miami',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Miami Heat',
#      'name': 'Heat'},
#     'home_team_score': 94,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 25,
#      'abbreviation': 'POR',
#      'city': 'Portland',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Portland Trail Blazers',
#      'name': 'Trail Blazers'},
#     'visitor_team_score': 124},
#    {'id': 1458,
#     'date': '1991-12-04T00:00:00.000Z',
#     'home_team': {'id': 13,
#      'abbreviation': 'LAC',
#      'city': 'LA',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'LA Clippers',
#      'name': 'Clippers'},
#     'home_team_score': 92,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 27,
#      'abbreviation': 'SAS',
#      'city': 'San Antonio',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'San Antonio Spurs',
#      'name': 'Spurs'},
#     'visitor_team_score': 81},
#    {'id': 1459,
#     'date': '1991-12-05T00:00:00.000Z',
#     'home_team': {'id': 11,
#      'abbreviation': 'HOU',
#      'city': 'Houston',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Houston Rockets',
#      'name': 'Rockets'},
#     'home_team_score': 97,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 1,
#      'abbreviation': 'ATL',
#      'city': 'Atlanta',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Atlanta Hawks',
#      'name': 'Hawks'},
#     'visitor_team_score': 109},
#    {'id': 1460,
#     'date': '1991-12-06T00:00:00.000Z',
#     'home_team': {'id': 27,
#      'abbreviation': 'SAS',
#      'city': 'San Antonio',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'San Antonio Spurs',
#      'name': 'Spurs'},
#     'home_team_score': 92,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 29,
#      'abbreviation': 'UTA',
#      'city': 'Utah',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Utah Jazz',
#      'name': 'Jazz'},
#     'visitor_team_score': 93},
#    {'id': 1461,
#     'date': '1991-12-07T00:00:00.000Z',
#     'home_team': {'id': 12,
#      'abbreviation': 'IND',
#      'city': 'Indiana',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Indiana Pacers',
#      'name': 'Pacers'},
#     'home_team_score': 112,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 25,
#      'abbreviation': 'POR',
#      'city': 'Portland',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Portland Trail Blazers',
#      'name': 'Trail Blazers'},
#     'visitor_team_score': 115},
#    {'id': 1462,
#     'date': '1991-12-10T00:00:00.000Z',
#     'home_team': {'id': 10,
#      'abbreviation': 'GSW',
#      'city': 'Golden State',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Golden State Warriors',
#      'name': 'Warriors'},
#     'home_team_score': 117,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 13,
#      'abbreviation': 'LAC',
#      'city': 'LA',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'LA Clippers',
#      'name': 'Clippers'},
#     'visitor_team_score': 127},
#    {'id': 1463,
#     'date': '1991-12-14T00:00:00.000Z',
#     'home_team': {'id': 10,
#      'abbreviation': 'GSW',
#      'city': 'Golden State',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Golden State Warriors',
#      'name': 'Warriors'},
#     'home_team_score': 128,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 22,
#      'abbreviation': 'ORL',
#      'city': 'Orlando',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Orlando Magic',
#      'name': 'Magic'},
#     'visitor_team_score': 107},
#    {'id': 1566,
#     'date': '1991-11-08T00:00:00.000Z',
#     'home_team': {'id': 13,
#      'abbreviation': 'LAC',
#      'city': 'LA',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'LA Clippers',
#      'name': 'Clippers'},
#     'home_team_score': 106,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 8,
#      'abbreviation': 'DEN',
#      'city': 'Denver',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Denver Nuggets',
#      'name': 'Nuggets'},
#     'visitor_team_score': 82},
#    {'id': 1567,
#     'date': '1991-11-09T00:00:00.000Z',
#     'home_team': {'id': 20,
#      'abbreviation': 'NYK',
#      'city': 'New York',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'New York Knicks',
#      'name': 'Knicks'},
#     'home_team_score': 118,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 4,
#      'abbreviation': 'CHA',
#      'city': 'Charlotte',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Charlotte Hornets',
#      'name': 'Hornets'},
#     'visitor_team_score': 113},
#    {'id': 1568,
#     'date': '1991-11-12T00:00:00.000Z',
#     'home_team': {'id': 7,
#      'abbreviation': 'DAL',
#      'city': 'Dallas',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Dallas Mavericks',
#      'name': 'Mavericks'},
#     'home_team_score': 92,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 11,
#      'abbreviation': 'HOU',
#      'city': 'Houston',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Houston Rockets',
#      'name': 'Rockets'},
#     'visitor_team_score': 98},
#    {'id': 1569,
#     'date': '1991-11-13T00:00:00.000Z',
#     'home_team': {'id': 12,
#      'abbreviation': 'IND',
#      'city': 'Indiana',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Indiana Pacers',
#      'name': 'Pacers'},
#     'home_team_score': 110,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 20,
#      'abbreviation': 'NYK',
#      'city': 'New York',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'New York Knicks',
#      'name': 'Knicks'},
#     'visitor_team_score': 107},
#    {'id': 1570,
#     'date': '1991-11-15T00:00:00.000Z',
#     'home_team': {'id': 2,
#      'abbreviation': 'BOS',
#      'city': 'Boston',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Boston Celtics',
#      'name': 'Celtics'},
#     'home_team_score': 122,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 23,
#      'abbreviation': 'PHI',
#      'city': 'Philadelphia',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Philadelphia 76ers',
#      'name': '76ers'},
#     'visitor_team_score': 97},
#    {'id': 1571,
#     'date': '1991-11-16T00:00:00.000Z',
#     'home_team': {'id': 9,
#      'abbreviation': 'DET',
#      'city': 'Detroit',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Detroit Pistons',
#      'name': 'Pistons'},
#     'home_team_score': 86,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 23,
#      'abbreviation': 'PHI',
#      'city': 'Philadelphia',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Philadelphia 76ers',
#      'name': '76ers'},
#     'visitor_team_score': 89},
#    {'id': 1572,
#     'date': '1991-11-20T00:00:00.000Z',
#     'home_team': {'id': 22,
#      'abbreviation': 'ORL',
#      'city': 'Orlando',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Orlando Magic',
#      'name': 'Magic'},
#     'home_team_score': 102,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 29,
#      'abbreviation': 'UTA',
#      'city': 'Utah',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Utah Jazz',
#      'name': 'Jazz'},
#     'visitor_team_score': 107},
#    {'id': 1573,
#     'date': '1991-11-21T00:00:00.000Z',
#     'home_team': {'id': 17,
#      'abbreviation': 'MIL',
#      'city': 'Milwaukee',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Milwaukee Bucks',
#      'name': 'Bucks'},
#     'home_team_score': 112,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 30,
#      'abbreviation': 'WAS',
#      'city': 'Washington',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Washington Wizards',
#      'name': 'Wizards'},
#     'visitor_team_score': 87},
#    {'id': 1574,
#     'date': '1991-11-22T00:00:00.000Z',
#     'home_team': {'id': 23,
#      'abbreviation': 'PHI',
#      'city': 'Philadelphia',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Philadelphia 76ers',
#      'name': '76ers'},
#     'home_team_score': 92,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 1,
#      'abbreviation': 'ATL',
#      'city': 'Atlanta',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Atlanta Hawks',
#      'name': 'Hawks'},
#     'visitor_team_score': 99},
#    {'id': 1575,
#     'date': '1991-11-23T00:00:00.000Z',
#     'home_team': {'id': 20,
#      'abbreviation': 'NYK',
#      'city': 'New York',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'New York Knicks',
#      'name': 'Knicks'},
#     'home_team_score': 100,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 23,
#      'abbreviation': 'PHI',
#      'city': 'Philadelphia',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Philadelphia 76ers',
#      'name': '76ers'},
#     'visitor_team_score': 92},
#    {'id': 1576,
#     'date': '1991-11-26T00:00:00.000Z',
#     'home_team': {'id': 22,
#      'abbreviation': 'ORL',
#      'city': 'Orlando',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Orlando Magic',
#      'name': 'Magic'},
#     'home_team_score': 87,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 14,
#      'abbreviation': 'LAL',
#      'city': 'Los Angeles',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Los Angeles Lakers',
#      'name': 'Lakers'},
#     'visitor_team_score': 98},
#    {'id': 1577,
#     'date': '1991-11-27T00:00:00.000Z',
#     'home_team': {'id': 6,
#      'abbreviation': 'CLE',
#      'city': 'Cleveland',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Cleveland Cavaliers',
#      'name': 'Cavaliers'},
#     'home_team_score': 107,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 23,
#      'abbreviation': 'PHI',
#      'city': 'Philadelphia',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Philadelphia 76ers',
#      'name': '76ers'},
#     'visitor_team_score': 97},
#    {'id': 1578,
#     'date': '1991-11-29T00:00:00.000Z',
#     'home_team': {'id': 8,
#      'abbreviation': 'DEN',
#      'city': 'Denver',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Denver Nuggets',
#      'name': 'Nuggets'},
#     'home_team_score': 101,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 21,
#      'abbreviation': 'OKC',
#      'city': 'Oklahoma City',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Oklahoma City Thunder',
#      'name': 'Thunder'},
#     'visitor_team_score': 90},
#    {'id': 1579,
#     'date': '1991-11-30T00:00:00.000Z',
#     'home_team': {'id': 27,
#      'abbreviation': 'SAS',
#      'city': 'San Antonio',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'San Antonio Spurs',
#      'name': 'Spurs'},
#     'home_team_score': 119,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 21,
#      'abbreviation': 'OKC',
#      'city': 'Oklahoma City',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Oklahoma City Thunder',
#      'name': 'Thunder'},
#     'visitor_team_score': 101},
#    {'id': 1580,
#     'date': '1991-12-03T00:00:00.000Z',
#     'home_team': {'id': 3,
#      'abbreviation': 'BKN',
#      'city': 'Brooklyn',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Brooklyn Nets',
#      'name': 'Nets'},
#     'home_team_score': 88,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 23,
#      'abbreviation': 'PHI',
#      'city': 'Philadelphia',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Philadelphia 76ers',
#      'name': '76ers'},
#     'visitor_team_score': 86},
#    {'id': 1581,
#     'date': '1991-12-04T00:00:00.000Z',
#     'home_team': {'id': 22,
#      'abbreviation': 'ORL',
#      'city': 'Orlando',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Orlando Magic',
#      'name': 'Magic'},
#     'home_team_score': 115,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 25,
#      'abbreviation': 'POR',
#      'city': 'Portland',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Portland Trail Blazers',
#      'name': 'Trail Blazers'},
#     'visitor_team_score': 124},
#    {'id': 1582,
#     'date': '1991-12-05T00:00:00.000Z',
#     'home_team': {'id': 9,
#      'abbreviation': 'DET',
#      'city': 'Detroit',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Detroit Pistons',
#      'name': 'Pistons'},
#     'home_team_score': 101,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
# ...
#      'full_name': 'Washington Wizards',
#      'name': 'Wizards'},
#     'home_team_score': 100,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 5,
#      'abbreviation': 'CHI',
#      'city': 'Chicago',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Chicago Bulls',
#      'name': 'Bulls'},
#     'visitor_team_score': 113},
#    {'id': 2134,
#     'date': '1991-12-15T00:00:00.000Z',
#     'home_team': {'id': 14,
#      'abbreviation': 'LAL',
#      'city': 'Los Angeles',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Los Angeles Lakers',
#      'name': 'Lakers'},
#     'home_team_score': 110,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 26,
#      'abbreviation': 'SAC',
#      'city': 'Sacramento',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Sacramento Kings',
#      'name': 'Kings'},
#     'visitor_team_score': 94},
#    {'id': 2135,
#     'date': '1991-12-16T00:00:00.000Z',
#     'home_team': {'id': 9,
#      'abbreviation': 'DET',
#      'city': 'Detroit',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Detroit Pistons',
#      'name': 'Pistons'},
#     'home_team_score': 103,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 8,
#      'abbreviation': 'DEN',
#      'city': 'Denver',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Denver Nuggets',
#      'name': 'Nuggets'},
#     'visitor_team_score': 89},
#    {'id': 2244,
#     'date': '1991-12-17T00:00:00.000Z',
#     'home_team': {'id': 21,
#      'abbreviation': 'OKC',
#      'city': 'Oklahoma City',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Oklahoma City Thunder',
#      'name': 'Thunder'},
#     'home_team_score': 116,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 13,
#      'abbreviation': 'LAC',
#      'city': 'LA',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'LA Clippers',
#      'name': 'Clippers'},
#     'visitor_team_score': 99},
#    {'id': 2245,
#     'date': '1991-12-21T00:00:00.000Z',
#     'home_team': {'id': 18,
#      'abbreviation': 'MIN',
#      'city': 'Minnesota',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Minnesota Timberwolves',
#      'name': 'Timberwolves'},
#     'home_team_score': 87,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 13,
#      'abbreviation': 'LAC',
#      'city': 'LA',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'LA Clippers',
#      'name': 'Clippers'},
#     'visitor_team_score': 100},
#    {'id': 2389,
#     'date': '1991-12-17T00:00:00.000Z',
#     'home_team': {'id': 20,
#      'abbreviation': 'NYK',
#      'city': 'New York',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'New York Knicks',
#      'name': 'Knicks'},
#     'home_team_score': 102,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 3,
#      'abbreviation': 'BKN',
#      'city': 'Brooklyn',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Brooklyn Nets',
#      'name': 'Nets'},
#     'visitor_team_score': 94},
#    {'id': 2390,
#     'date': '1991-12-18T00:00:00.000Z',
#     'home_team': {'id': 2,
#      'abbreviation': 'BOS',
#      'city': 'Boston',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Boston Celtics',
#      'name': 'Celtics'},
#     'home_team_score': 131,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 17,
#      'abbreviation': 'MIL',
#      'city': 'Milwaukee',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Milwaukee Bucks',
#      'name': 'Bucks'},
#     'visitor_team_score': 117},
#    {'id': 2391,
#     'date': '1991-12-19T00:00:00.000Z',
#     'home_team': {'id': 21,
#      'abbreviation': 'OKC',
#      'city': 'Oklahoma City',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Oklahoma City Thunder',
#      'name': 'Thunder'},
#     'home_team_score': 119,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 8,
#      'abbreviation': 'DEN',
#      'city': 'Denver',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Denver Nuggets',
#      'name': 'Nuggets'},
#     'visitor_team_score': 106},
#    {'id': 2392,
#     'date': '1991-12-20T00:00:00.000Z',
#     'home_team': {'id': 9,
#      'abbreviation': 'DET',
#      'city': 'Detroit',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Detroit Pistons',
#      'name': 'Pistons'},
#     'home_team_score': 112,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 14,
#      'abbreviation': 'LAL',
#      'city': 'Los Angeles',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Los Angeles Lakers',
#      'name': 'Lakers'},
#     'visitor_team_score': 93},
#    {'id': 2393,
#     'date': '1991-12-21T00:00:00.000Z',
#     'home_team': {'id': 21,
#      'abbreviation': 'OKC',
#      'city': 'Oklahoma City',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Oklahoma City Thunder',
#      'name': 'Thunder'},
#     'home_team_score': 120,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 10,
#      'abbreviation': 'GSW',
#      'city': 'Golden State',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Golden State Warriors',
#      'name': 'Warriors'},
#     'visitor_team_score': 112},
#    {'id': 2394,
#     'date': '1991-12-23T00:00:00.000Z',
#     'home_team': {'id': 16,
#      'abbreviation': 'MIA',
#      'city': 'Miami',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Miami Heat',
#      'name': 'Heat'},
#     'home_team_score': 113,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 22,
#      'abbreviation': 'ORL',
#      'city': 'Orlando',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Orlando Magic',
#      'name': 'Magic'},
#     'visitor_team_score': 102},
#    {'id': 2395,
#     'date': '1991-12-25T00:00:00.000Z',
#     'home_team': {'id': 5,
#      'abbreviation': 'CHI',
#      'city': 'Chicago',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Chicago Bulls',
#      'name': 'Bulls'},
#     'home_team_score': 121,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 2,
#      'abbreviation': 'BOS',
#      'city': 'Boston',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Boston Celtics',
#      'name': 'Celtics'},
#     'visitor_team_score': 99},
#    {'id': 2396,
#     'date': '1991-12-26T00:00:00.000Z',
#     'home_team': {'id': 24,
#      'abbreviation': 'PHX',
#      'city': 'Phoenix',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Phoenix Suns',
#      'name': 'Suns'},
#     'home_team_score': 132,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 16,
#      'abbreviation': 'MIA',
#      'city': 'Miami',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Miami Heat',
#      'name': 'Heat'},
#     'visitor_team_score': 104},
#    {'id': 2397,
#     'date': '1991-12-26T00:00:00.000Z',
#     'home_team': {'id': 3,
#      'abbreviation': 'BKN',
#      'city': 'Brooklyn',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Brooklyn Nets',
#      'name': 'Nets'},
#     'home_team_score': 99,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 11,
#      'abbreviation': 'HOU',
#      'city': 'Houston',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Houston Rockets',
#      'name': 'Rockets'},
#     'visitor_team_score': 93},
#    {'id': 2398,
#     'date': '1991-12-28T00:00:00.000Z',
#     'home_team': {'id': 30,
#      'abbreviation': 'WAS',
#      'city': 'Washington',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Washington Wizards',
#      'name': 'Wizards'},
#     'home_team_score': 129,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 4,
#      'abbreviation': 'CHA',
#      'city': 'Charlotte',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Charlotte Hornets',
#      'name': 'Hornets'},
#     'visitor_team_score': 124},
#    {'id': 2399,
#     'date': '1991-12-29T00:00:00.000Z',
#     'home_team': {'id': 22,
#      'abbreviation': 'ORL',
#      'city': 'Orlando',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Orlando Magic',
#      'name': 'Magic'},
#     'home_team_score': 87,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 27,
#      'abbreviation': 'SAS',
#      'city': 'San Antonio',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'San Antonio Spurs',
#      'name': 'Spurs'},
#     'visitor_team_score': 96},
#    {'id': 2400,
#     'date': '1991-12-30T00:00:00.000Z',
#     'home_team': {'id': 8,
#      'abbreviation': 'DEN',
#      'city': 'Denver',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Denver Nuggets',
#      'name': 'Nuggets'},
#     'home_team_score': 109,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 23,
#      'abbreviation': 'PHI',
#      'city': 'Philadelphia',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Philadelphia 76ers',
#      'name': '76ers'},
#     'visitor_team_score': 93},
#    {'id': 2401,
#     'date': '1992-01-02T00:00:00.000Z',
#     'home_team': {'id': 18,
#      'abbreviation': 'MIN',
#      'city': 'Minnesota',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Minnesota Timberwolves',
#      'name': 'Timberwolves'},
#     'home_team_score': 91,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 17,
#      'abbreviation': 'MIL',
#      'city': 'Milwaukee',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Milwaukee Bucks',
#      'name': 'Bucks'},
#     'visitor_team_score': 92},
#    {'id': 2402,
#     'date': '1992-01-03T00:00:00.000Z',
#     'home_team': {'id': 2,
#      'abbreviation': 'BOS',
#      'city': 'Boston',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Boston Celtics',
#      'name': 'Celtics'},
#     'home_team_score': 100,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 6,
#      'abbreviation': 'CLE',
#      'city': 'Cleveland',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Cleveland Cavaliers',
#      'name': 'Cavaliers'},
#     'visitor_team_score': 111},
#    {'id': 2403,
#     'date': '1992-01-04T00:00:00.000Z',
#     'home_team': {'id': 27,
#      'abbreviation': 'SAS',
#      'city': 'San Antonio',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'San Antonio Spurs',
#      'name': 'Spurs'},
#     'home_team_score': 110,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 11,
#      'abbreviation': 'HOU',
#      'city': 'Houston',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Houston Rockets',
#      'name': 'Rockets'},
#     'visitor_team_score': 112},
#    {'id': 2518,
#     'date': '1991-12-17T00:00:00.000Z',
#     'home_team': {'id': 5,
#      'abbreviation': 'CHI',
#      'city': 'Chicago',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Chicago Bulls',
#      'name': 'Bulls'},
#     'home_team_score': 89,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 14,
#      'abbreviation': 'LAL',
#      'city': 'Los Angeles',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Los Angeles Lakers',
#      'name': 'Lakers'},
#     'visitor_team_score': 102},
#    {'id': 2519,
#     'date': '1991-12-18T00:00:00.000Z',
#     'home_team': {'id': 27,
#      'abbreviation': 'SAS',
#      'city': 'San Antonio',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'San Antonio Spurs',
#      'name': 'Spurs'},
#     'home_team_score': 93,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 30,
#      'abbreviation': 'WAS',
#      'city': 'Washington',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Washington Wizards',
#      'name': 'Wizards'},
#     'visitor_team_score': 96},
#    {'id': 2520,
#     'date': '1991-12-19T00:00:00.000Z',
#     'home_team': {'id': 11,
#      'abbreviation': 'HOU',
#      'city': 'Houston',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Houston Rockets',
#      'name': 'Rockets'},
#     'home_team_score': 109,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 26,
#      'abbreviation': 'SAC',
#      'city': 'Sacramento',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Sacramento Kings',
#      'name': 'Kings'},
#     'visitor_team_score': 102},
#    {'id': 2521,
#     'date': '1991-12-20T00:00:00.000Z',
#     'home_team': {'id': 24,
#      'abbreviation': 'PHX',
#      'city': 'Phoenix',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Phoenix Suns',
#      'name': 'Suns'},
#     'home_team_score': 116,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 27,
#      'abbreviation': 'SAS',
#      'city': 'San Antonio',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'San Antonio Spurs',
#      'name': 'Spurs'},
#     'visitor_team_score': 91},
#    {'id': 2522,
#     'date': '1991-12-21T00:00:00.000Z',
#     'home_team': {'id': 17,
#      'abbreviation': 'MIL',
#      'city': 'Milwaukee',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Milwaukee Bucks',
#      'name': 'Bucks'},
#     'home_team_score': 110,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 23,
#      'abbreviation': 'PHI',
#      'city': 'Philadelphia',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Philadelphia 76ers',
#      'name': '76ers'},
#     'visitor_team_score': 97},
#    {'id': 2523,
#     'date': '1991-12-22T00:00:00.000Z',
#     'home_team': {'id': 14,
#      'abbreviation': 'LAL',
#      'city': 'Los Angeles',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Los Angeles Lakers',
#      'name': 'Lakers'},
#     'home_team_score': 88,
#     'period': 4,
#     'postseason': False,
#     'season': 1991,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team': {'id': 24,
#      'abbreviation': 'PHX',
#      'city': 'Phoenix',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Phoenix Suns',
#      'name': 'Suns'},
#     'visitor_team_score': 100}],
#   'meta': {'total_pages': 12,
#    'current_page': 2,
#    'next_page': 3,
#    'per_page': 100,
#    'total_count': 1180}}]

# %%
games_1991 = write_json_file(games,"notebooks/games")

# %%
len(games_1991)
# Out:
# 2

# %% [markdown]
# ## Exercise 1.3
# - It is required to obtain all players. No need to rename/remove fields from the response.

# %%
# url and params to the API call
players_url = 'https://www.balldontlie.io/api/v1/players'
players_params= {"per_page":100} # It must be a dictionary

# %%
# Function to the API call
players = paginate_api_calls(players_url, players_params)
# Out:
# The request was successful, the status code was returned: 200  and as reason for the status code: OK

# %%
players
# Out:
# [{'data': [{'id': 14,
#     'first_name': 'Ike',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Anigbogu',
#     'position': 'C',
#     'team': {'id': 12,
#      'abbreviation': 'IND',
#      'city': 'Indiana',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Indiana Pacers',
#      'name': 'Pacers'},
#     'weight_pounds': None},
#    {'id': 25,
#     'first_name': 'Ron',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Baker',
#     'position': 'G',
#     'team': {'id': 20,
#      'abbreviation': 'NYK',
#      'city': 'New York',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'New York Knicks',
#      'name': 'Knicks'},
#     'weight_pounds': None},
#    {'id': 47,
#     'first_name': 'Jabari',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Bird',
#     'position': 'G',
#     'team': {'id': 2,
#      'abbreviation': 'BOS',
#      'city': 'Boston',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Boston Celtics',
#      'name': 'Celtics'},
#     'weight_pounds': None},
#    {'id': 67,
#     'first_name': 'MarShon',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Brooks',
#     'position': 'G',
#     'team': {'id': 15,
#      'abbreviation': 'MEM',
#      'city': 'Memphis',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Memphis Grizzlies',
#      'name': 'Grizzlies'},
#     'weight_pounds': None},
#    {'id': 71,
#     'first_name': 'Lorenzo',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Brown',
#     'position': 'G',
#     'team': {'id': 28,
#      'abbreviation': 'TOR',
#      'city': 'Toronto',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Toronto Raptors',
#      'name': 'Raptors'},
#     'weight_pounds': None},
#    {'id': 90,
#     'first_name': 'Omri',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Casspi',
#     'position': 'F',
#     'team': {'id': 15,
#      'abbreviation': 'MEM',
#      'city': 'Memphis',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Memphis Grizzlies',
#      'name': 'Grizzlies'},
#     'weight_pounds': None},
#    {'id': 1,
#     'first_name': 'Alex',
#     'height_feet': 6,
#     'height_inches': 6,
#     'last_name': 'Abrines',
#     'position': 'G',
#     'team': {'id': 21,
#      'abbreviation': 'OKC',
#      'city': 'Oklahoma City',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Oklahoma City Thunder',
#      'name': 'Thunder'},
#     'weight_pounds': 200},
#    {'id': 119,
#     'first_name': 'Tyler',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Davis',
#     'position': 'C',
#     'team': {'id': 21,
#      'abbreviation': 'OKC',
#      'city': 'Oklahoma City',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Oklahoma City Thunder',
#      'name': 'Thunder'},
#     'weight_pounds': None},
#    {'id': 149,
#     'first_name': 'Keenan',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Evans',
#     'position': 'G',
#     'team': {'id': 9,
#      'abbreviation': 'DET',
#      'city': 'Detroit',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Detroit Pistons',
#      'name': 'Pistons'},
#     'weight_pounds': None},
#    {'id': 179,
#     'first_name': 'Marcin',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Gortat',
#     'position': 'C',
#     'team': {'id': 13,
#      'abbreviation': 'LAC',
#      'city': 'LA',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'LA Clippers',
#      'name': 'Clippers'},
#     'weight_pounds': None},
#    {'id': 1593,
#     'first_name': 'Andrew',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Bogut',
#     'position': 'F',
#     'team': {'id': 10,
#      'abbreviation': 'GSW',
#      'city': 'Golden State',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Golden State Warriors',
#      'name': 'Warriors'},
#     'weight_pounds': None},
#    {'id': 241,
#     'first_name': 'Amir',
#     'height_feet': 6,
#     'height_inches': 9,
#     'last_name': 'Johnson',
#     'position': 'C-F',
#     'team': {'id': 23,
#      'abbreviation': 'PHI',
#      'city': 'Philadelphia',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Philadelphia 76ers',
#      'name': '76ers'},
#     'weight_pounds': 240},
#    {'id': 392,
#     'first_name': 'Malachi',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Richardson',
#     'position': 'G',
#     'team': {'id': 29,
#      'abbreviation': 'UTA',
#      'city': 'Utah',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Utah Jazz',
#      'name': 'Jazz'},
#     'weight_pounds': None},
#    {'id': 281,
#     'first_name': 'Zach',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Lofton',
#     'position': 'G',
#     'team': {'id': 9,
#      'abbreviation': 'DET',
#      'city': 'Detroit',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Detroit Pistons',
#      'name': 'Pistons'},
#     'weight_pounds': None},
#    {'id': 263,
#     'first_name': 'Kosta',
#     'height_feet': 7,
#     'height_inches': 0,
#     'last_name': 'Koufos',
#     'position': 'C',
#     'team': {'id': 26,
#      'abbreviation': 'SAC',
#      'city': 'Sacramento',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Sacramento Kings',
#      'name': 'Kings'},
#     'weight_pounds': 245},
#    {'id': 382,
#     'first_name': 'Billy',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Preston',
#     'position': 'F',
#     'team': {'id': 6,
#      'abbreviation': 'CLE',
#      'city': 'Cleveland',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Cleveland Cavaliers',
#      'name': 'Cavaliers'},
#     'weight_pounds': None},
#    {'id': 384,
#     'first_name': 'Zhou',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Qi',
#     'position': 'F-C',
#     'team': {'id': 11,
#      'abbreviation': 'HOU',
#      'city': 'Houston',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Houston Rockets',
#      'name': 'Rockets'},
#     'weight_pounds': None},
#    {'id': 388,
#     'first_name': 'Zach',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Randolph',
#     'position': 'F',
#     'team': {'id': 26,
#      'abbreviation': 'SAC',
#      'city': 'Sacramento',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Sacramento Kings',
#      'name': 'Kings'},
#     'weight_pounds': None},
#    {'id': 430,
#     'first_name': 'DJ',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Stephens',
#     'position': 'G-F',
#     'team': {'id': 15,
#      'abbreviation': 'MEM',
#      'city': 'Memphis',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Memphis Grizzlies',
#      'name': 'Grizzlies'},
#     'weight_pounds': None},
#    {'id': 437,
#     'first_name': 'Milos',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Teodosic',
#     'position': 'G',
#     'team': {'id': 13,
#      'abbreviation': 'LAC',
#      'city': 'LA',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'LA Clippers',
#      'name': 'Clippers'},
#     'weight_pounds': None},
#    {'id': 448,
#     'first_name': 'Gary',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Trent Jr.',
#     'position': 'G',
#     'team': {'id': 25,
#      'abbreviation': 'POR',
#      'city': 'Portland',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Portland Trail Blazers',
#      'name': 'Trail Blazers'},
#     'weight_pounds': None},
#    {'id': 494,
#     'first_name': 'Michael',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Smith',
#     'position': '',
#     'team': {'id': 2,
#      'abbreviation': 'BOS',
#      'city': 'Boston',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Boston Celtics',
#      'name': 'Celtics'},
#     'weight_pounds': None},
#    {'id': 495,
#     'first_name': 'John',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Morton',
#     'position': '',
#     'team': {'id': 6,
#      'abbreviation': 'CLE',
#      'city': 'Cleveland',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Cleveland Cavaliers',
#      'name': 'Cavaliers'},
#     'weight_pounds': None},
#    {'id': 496,
#     'first_name': 'Howard',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Wright',
#     'position': '',
#     'team': {'id': 1,
#      'abbreviation': 'ATL',
#      'city': 'Atlanta',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Atlanta Hawks',
#      'name': 'Hawks'},
#     'weight_pounds': None},
#    {'id': 497,
#     'first_name': 'Michael',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Ansley',
#     'position': '',
#     'team': {'id': 22,
#      'abbreviation': 'ORL',
#      'city': 'Orlando',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Orlando Magic',
#      'name': 'Magic'},
#     'weight_pounds': None},
#    {'id': 498,
#     'first_name': 'John',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Salley',
#     'position': '',
#     'team': {'id': 9,
#      'abbreviation': 'DET',
#      'city': 'Detroit',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Detroit Pistons',
#      'name': 'Pistons'},
#     'weight_pounds': None},
#    {'id': 499,
#     'first_name': 'Dan',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Schayes',
#     'position': '',
#     'team': {'id': 17,
#      'abbreviation': 'MIL',
#      'city': 'Milwaukee',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Milwaukee Bucks',
#      'name': 'Bucks'},
#     'weight_pounds': None},
#    {'id': 500,
#     'first_name': 'Mark',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Eaton',
#     'position': '',
#     'team': {'id': 29,
#      'abbreviation': 'UTA',
#      'city': 'Utah',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Utah Jazz',
#      'name': 'Jazz'},
#     'weight_pounds': None},
#    {'id': 501,
#     'first_name': 'Kevin',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Johnson',
#     'position': '',
#     'team': {'id': 24,
#      'abbreviation': 'PHX',
#      'city': 'Phoenix',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Phoenix Suns',
#      'name': 'Suns'},
#     'weight_pounds': None},
#    {'id': 502,
#     'first_name': 'Danny',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Ainge',
#     'position': '',
#     'team': {'id': 25,
#      'abbreviation': 'POR',
#      'city': 'Portland',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Portland Trail Blazers',
#      'name': 'Trail Blazers'},
#     'weight_pounds': None},
#    {'id': 503,
#     'first_name': 'Kenny',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Smith',
#     'position': '',
#     'team': {'id': 11,
#      'abbreviation': 'HOU',
#      'city': 'Houston',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Houston Rockets',
#      'name': 'Rockets'},
#     'weight_pounds': None},
#    {'id': 504,
#     'first_name': 'Randy',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Breuer',
#     'position': '',
#     'team': {'id': 18,
#      'abbreviation': 'MIN',
#      'city': 'Minnesota',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Minnesota Timberwolves',
#      'name': 'Timberwolves'},
#     'weight_pounds': None},
#    {'id': 505,
#     'first_name': 'Herb',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Williams',
#     'position': '',
#     'team': {'id': 7,
#      'abbreviation': 'DAL',
#      'city': 'Dallas',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Dallas Mavericks',
#      'name': 'Mavericks'},
#     'weight_pounds': None},
#    {'id': 506,
#     'first_name': 'Joe',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Wolf',
#     'position': '',
#     'team': {'id': 8,
#      'abbreviation': 'DEN',
#      'city': 'Denver',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Denver Nuggets',
#      'name': 'Nuggets'},
#     'weight_pounds': None},
#    {'id': 507,
#     'first_name': 'Steve',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Johnson',
#     'position': '',
#     'team': {'id': 10,
#      'abbreviation': 'GSW',
#      'city': 'Golden State',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Golden State Warriors',
#      'name': 'Warriors'},
#     'weight_pounds': None},
#    {'id': 508,
#     'first_name': 'Glen',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Rice',
#     'position': '',
#     'team': {'id': 16,
#      'abbreviation': 'MIA',
#      'city': 'Miami',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Miami Heat',
#      'name': 'Heat'},
#     'weight_pounds': None},
#    {'id': 509,
#     'first_name': 'Greg',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Foster',
#     'position': '',
#     'team': {'id': 30,
#      'abbreviation': 'WAS',
#      'city': 'Washington',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Washington Wizards',
#      'name': 'Wizards'},
#     'weight_pounds': None},
#    {'id': 510,
#     'first_name': 'Larry',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Nance',
#     'position': '',
#     'team': {'id': 6,
#      'abbreviation': 'CLE',
#      'city': 'Cleveland',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Cleveland Cavaliers',
#      'name': 'Cavaliers'},
#     'weight_pounds': None},
#    {'id': 511,
#     'first_name': 'Duane',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Ferrell',
#     'position': '',
#     'team': {'id': 1,
#      'abbreviation': 'ATL',
#      'city': 'Atlanta',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Atlanta Hawks',
#      'name': 'Hawks'},
#     'weight_pounds': None},
#    {'id': 512,
#     'first_name': 'Nick',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Anderson',
#     'position': '',
#     'team': {'id': 22,
#      'abbreviation': 'ORL',
#      'city': 'Orlando',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Orlando Magic',
#      'name': 'Magic'},
#     'weight_pounds': None},
#    {'id': 513,
#     'first_name': 'Joe',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Dumars',
#     'position': '',
#     'team': {'id': 9,
#      'abbreviation': 'DET',
#      'city': 'Detroit',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Detroit Pistons',
#      'name': 'Pistons'},
#     'weight_pounds': None},
#    {'id': 514,
#     'first_name': 'Jay',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Humphries',
#     'position': '',
#     'team': {'id': 17,
#      'abbreviation': 'MIL',
#      'city': 'Milwaukee',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Milwaukee Bucks',
#      'name': 'Bucks'},
#     'weight_pounds': None},
#    {'id': 515,
#     'first_name': 'Darrell',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Griffith',
#     'position': '',
#     'team': {'id': 29,
#      'abbreviation': 'UTA',
#      'city': 'Utah',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Utah Jazz',
#      'name': 'Jazz'},
#     'weight_pounds': None},
#    {'id': 516,
#     'first_name': 'Dan',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Majerle',
#     'position': '',
#     'team': {'id': 24,
#      'abbreviation': 'PHX',
#      'city': 'Phoenix',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Phoenix Suns',
#      'name': 'Suns'},
#     'weight_pounds': None},
#    {'id': 517,
#     'first_name': 'Tom',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Chambers',
#     'position': '',
#     'team': {'id': 24,
#      'abbreviation': 'PHX',
#      'city': 'Phoenix',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Phoenix Suns',
#      'name': 'Suns'},
#     'weight_pounds': None},
#    {'id': 518,
#     'first_name': 'Alaa',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Abdelnaby',
#     'position': '',
#     'team': {'id': 25,
#      'abbreviation': 'POR',
#      'city': 'Portland',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Portland Trail Blazers',
#      'name': 'Trail Blazers'},
#     'weight_pounds': None},
#    {'id': 519,
#     'first_name': 'Adrian',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Caldwell',
#     'position': '',
#     'team': {'id': 11,
#      'abbreviation': 'HOU',
#      'city': 'Houston',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Houston Rockets',
#      'name': 'Rockets'},
#     'weight_pounds': None},
#    {'id': 520,
#     'first_name': 'Vernon',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Maxwell',
#     'position': '',
#     'team': {'id': 11,
#      'abbreviation': 'HOU',
#      'city': 'Houston',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Houston Rockets',
#      'name': 'Rockets'},
#     'weight_pounds': None},
#    {'id': 521,
#     'first_name': 'Doug',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'West',
#     'position': '',
#     'team': {'id': 18,
#      'abbreviation': 'MIN',
#      'city': 'Minnesota',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Minnesota Timberwolves',
#      'name': 'Timberwolves'},
#     'weight_pounds': None},
#    {'id': 522,
#     'first_name': 'Tony',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Campbell',
#     'position': '',
#     'team': {'id': 18,
#      'abbreviation': 'MIN',
#      'city': 'Minnesota',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Minnesota Timberwolves',
#      'name': 'Timberwolves'},
#     'weight_pounds': None},
#    {'id': 523,
#     'first_name': 'Roy',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Tarpley',
#     'position': '',
#     'team': {'id': 7,
#      'abbreviation': 'DAL',
#      'city': 'Dallas',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Dallas Mavericks',
#      'name': 'Mavericks'},
#     'weight_pounds': None},
#    {'id': 524,
#     'first_name': 'Anthony',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Cook',
#     'position': '',
#     'team': {'id': 8,
#      'abbreviation': 'DEN',
#      'city': 'Denver',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Denver Nuggets',
#      'name': 'Nuggets'},
#     'weight_pounds': None},
#    {'id': 525,
#     'first_name': 'Todd',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Lichti',
#     'position': '',
#     'team': {'id': 8,
#      'abbreviation': 'DEN',
#      'city': 'Denver',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Denver Nuggets',
#      'name': 'Nuggets'},
#     'weight_pounds': None},
#    {'id': 526,
#     'first_name': 'Tom',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Tolbert',
#     'position': '',
#     'team': {'id': 10,
#      'abbreviation': 'GSW',
#      'city': 'Golden State',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Golden State Warriors',
#      'name': 'Warriors'},
#     'weight_pounds': None},
#    {'id': 527,
#     'first_name': 'Billy',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Thompson',
#     'position': '',
#     'team': {'id': 16,
#      'abbreviation': 'MIA',
#      'city': 'Miami',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Miami Heat',
#      'name': 'Heat'},
#     'weight_pounds': None},
#    {'id': 528,
#     'first_name': 'Byron',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Irvin',
#     'position': '',
#     'team': {'id': 30,
#      'abbreviation': 'WAS',
#      'city': 'Washington',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Washington Wizards',
#      'name': 'Wizards'},
#     'weight_pounds': None},
#    {'id': 529,
#     'first_name': 'Mark',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Price',
#     'position': '',
#     'team': {'id': 6,
#      'abbreviation': 'CLE',
#      'city': 'Cleveland',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Cleveland Cavaliers',
#      'name': 'Cavaliers'},
#     'weight_pounds': None},
#    {'id': 530,
#     'first_name': 'Dominique',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Wilkins',
#     'position': '',
#     'team': {'id': 1,
#      'abbreviation': 'ATL',
#      'city': 'Atlanta',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Atlanta Hawks',
#      'name': 'Hawks'},
#     'weight_pounds': None},
#    {'id': 531,
#     'first_name': 'Dennis',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Scott',
#     'position': '',
#     'team': {'id': 22,
#      'abbreviation': 'ORL',
#      'city': 'Orlando',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Orlando Magic',
#      'name': 'Magic'},
#     'weight_pounds': None},
#    {'id': 532,
#     'first_name': 'Terry',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Catledge',
#     'position': '',
#     'team': {'id': 22,
#      'abbreviation': 'ORL',
#      'city': 'Orlando',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Orlando Magic',
#      'name': 'Magic'},
#     'weight_pounds': None},
#    {'id': 533,
#     'first_name': 'Bill',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Laimbeer',
#     'position': '',
#     'team': {'id': 9,
#      'abbreviation': 'DET',
#      'city': 'Detroit',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Detroit Pistons',
#      'name': 'Pistons'},
#     'weight_pounds': None},
#    {'id': 534,
#     'first_name': 'William',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Bedford',
#     'position': '',
#     'team': {'id': 9,
#      'abbreviation': 'DET',
#      'city': 'Detroit',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Detroit Pistons',
#      'name': 'Pistons'},
#     'weight_pounds': None},
#    {'id': 535,
#     'first_name': 'Ricky',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Pierce',
#     'position': '',
#     'team': {'id': 17,
#      'abbreviation': 'MIL',
#      'city': 'Milwaukee',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Milwaukee Bucks',
#      'name': 'Bucks'},
#     'weight_pounds': None},
#    {'id': 536,
#     'first_name': 'Blue',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Edwards',
#     'position': '',
#     'team': {'id': 29,
#      'abbreviation': 'UTA',
#      'city': 'Utah',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Utah Jazz',
#      'name': 'Jazz'},
#     'weight_pounds': None},
#    {'id': 537,
#     'first_name': 'Walter',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Palmer',
#     'position': '',
#     'team': {'id': 29,
#      'abbreviation': 'UTA',
#      'city': 'Utah',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Utah Jazz',
#      'name': 'Jazz'},
#     'weight_pounds': None},
#    {'id': 538,
#     'first_name': 'Mark',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'West',
#     'position': '',
#     'team': {'id': 24,
#      'abbreviation': 'PHX',
#      'city': 'Phoenix',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Phoenix Suns',
#      'name': 'Suns'},
#     'weight_pounds': None},
#    {'id': 539,
#     'first_name': 'Clifford',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Robinson',
#     'position': '',
#     'team': {'id': 25,
#      'abbreviation': 'POR',
#      'city': 'Portland',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Portland Trail Blazers',
#      'name': 'Trail Blazers'},
#     'weight_pounds': None},
#    {'id': 540,
#     'first_name': 'Hakeem',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Olajuwon',
#     'position': '',
#     'team': {'id': 11,
#      'abbreviation': 'HOU',
#      'city': 'Houston',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Houston Rockets',
#      'name': 'Rockets'},
#     'weight_pounds': None},
#    {'id': 541,
#     'first_name': 'Richard',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Coffey',
#     'position': '',
#     'team': {'id': 18,
#      'abbreviation': 'MIN',
#      'city': 'Minnesota',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Minnesota Timberwolves',
#      'name': 'Timberwolves'},
#     'weight_pounds': None},
#    {'id': 542,
#     'first_name': 'James',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Donaldson',
#     'position': '',
#     'team': {'id': 7,
#      'abbreviation': 'DAL',
#      'city': 'Dallas',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Dallas Mavericks',
#      'name': 'Mavericks'},
#     'weight_pounds': None},
#    {'id': 543,
#     'first_name': 'Jerome',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Lane',
#     'position': '',
#     'team': {'id': 8,
#      'abbreviation': 'DEN',
#      'city': 'Denver',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Denver Nuggets',
#      'name': 'Nuggets'},
#     'weight_pounds': None},
#    {'id': 544,
#     'first_name': 'Sarunas',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Marciulionis',
#     'position': '',
#     'team': {'id': 10,
#      'abbreviation': 'GSW',
#      'city': 'Golden State',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Golden State Warriors',
#      'name': 'Warriors'},
#     'weight_pounds': None},
#    {'id': 545,
#     'first_name': 'Grant',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Long',
#     'position': '',
#     'team': {'id': 16,
#      'abbreviation': 'MIA',
#      'city': 'Miami',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Miami Heat',
#      'name': 'Heat'},
#     'weight_pounds': None},
#    {'id': 546,
#     'first_name': 'Willie',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Burton',
#     'position': '',
#     'team': {'id': 16,
#      'abbreviation': 'MIA',
#      'city': 'Miami',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Miami Heat',
#      'name': 'Heat'},
#     'weight_pounds': None},
#    {'id': 547,
#     'first_name': 'Mark',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Alarie',
#     'position': '',
#     'team': {'id': 30,
#      'abbreviation': 'WAS',
#      'city': 'Washington',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Washington Wizards',
#      'name': 'Wizards'},
#     'weight_pounds': None},
#    {'id': 548,
#     'first_name': 'Winston',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Bennett',
#     'position': '',
#     'team': {'id': 6,
#      'abbreviation': 'CLE',
#      'city': 'Cleveland',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Cleveland Cavaliers',
#      'name': 'Cavaliers'},
#     'weight_pounds': None},
#    {'id': 549,
#     'first_name': 'Doc',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Rivers',
#     'position': '',
#     'team': {'id': 1,
#      'abbreviation': 'ATL',
#      'city': 'Atlanta',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Atlanta Hawks',
#      'name': 'Hawks'},
#     'weight_pounds': None},
#    {'id': 550,
#     'first_name': 'Tim',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'McCormick',
#     'position': '',
#     'team': {'id': 1,
#      'abbreviation': 'ATL',
#      'city': 'Atlanta',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Atlanta Hawks',
#      'name': 'Hawks'},
#     'weight_pounds': None},
#    {'id': 551,
#     'first_name': 'Scott',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Skiles',
#     'position': '',
#     'team': {'id': 22,
#      'abbreviation': 'ORL',
#      'city': 'Orlando',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Orlando Magic',
#      'name': 'Magic'},
#     'weight_pounds': None},
#    {'id': 552,
#     'first_name': 'Dennis',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Rodman',
#     'position': '',
#     'team': {'id': 9,
#      'abbreviation': 'DET',
#      'city': 'Detroit',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Detroit Pistons',
#      'name': 'Pistons'},
#     'weight_pounds': None},
#    {'id': 553,
#     'first_name': 'Greg',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Anderson',
#     'position': '',
#     'team': {'id': 17,
#      'abbreviation': 'MIL',
#      'city': 'Milwaukee',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Milwaukee Bucks',
#      'name': 'Bucks'},
#     'weight_pounds': None},
#    {'id': 554,
#     'first_name': 'Jeff',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Malone',
#     'position': '',
#     'team': {'id': 29,
#      'abbreviation': 'UTA',
#      'city': 'Utah',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Utah Jazz',
#      'name': 'Jazz'},
#     'weight_pounds': None},
#    {'id': 555,
#     'first_name': 'Cedric',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Ceballos',
#     'position': '',
#     'team': {'id': 24,
#      'abbreviation': 'PHX',
#      'city': 'Phoenix',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Phoenix Suns',
#      'name': 'Suns'},
#     'weight_pounds': None},
#    {'id': 556,
#     'first_name': 'Tim',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Perry',
#     'position': '',
#     'team': {'id': 24,
#      'abbreviation': 'PHX',
#      'city': 'Phoenix',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Phoenix Suns',
#      'name': 'Suns'},
#     'weight_pounds': None},
#    {'id': 557,
#     'first_name': 'Buck',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Williams',
#     'position': '',
#     'team': {'id': 25,
#      'abbreviation': 'POR',
#      'city': 'Portland',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Portland Trail Blazers',
#      'name': 'Trail Blazers'},
#     'weight_pounds': None},
#    {'id': 558,
#     'first_name': 'Dave',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Jamerson',
#     'position': '',
#     'team': {'id': 11,
#      'abbreviation': 'HOU',
#      'city': 'Houston',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Houston Rockets',
#      'name': 'Rockets'},
#     'weight_pounds': None},
#    {'id': 559,
#     'first_name': 'Scott',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Brooks',
#     'position': '',
#     'team': {'id': 18,
#      'abbreviation': 'MIN',
#      'city': 'Minnesota',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Minnesota Timberwolves',
#      'name': 'Timberwolves'},
#     'weight_pounds': None},
#    {'id': 560,
#     'first_name': 'Rolando',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Blackman',
#     'position': '',
#     'team': {'id': 7,
#      'abbreviation': 'DAL',
#      'city': 'Dallas',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Dallas Mavericks',
#      'name': 'Mavericks'},
#     'weight_pounds': None},
#    {'id': 561,
#     'first_name': 'Avery',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Johnson',
#     'position': '',
#     'team': {'id': 8,
#      'abbreviation': 'DEN',
#      'city': 'Denver',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Denver Nuggets',
#      'name': 'Nuggets'},
#     'weight_pounds': None},
#    {'id': 562,
#     'first_name': 'Rod',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Higgins',
#     'position': '',
#     'team': {'id': 10,
#      'abbreviation': 'GSW',
#      'city': 'Golden State',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Golden State Warriors',
#      'name': 'Warriors'},
#     'weight_pounds': None},
#    {'id': 563,
#     'first_name': 'Jon',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Sundvold',
#     'position': '',
#     'team': {'id': 16,
#      'abbreviation': 'MIA',
#      'city': 'Miami',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Miami Heat',
#      'name': 'Heat'},
#     'weight_pounds': None},
#    {'id': 564,
#     'first_name': 'A.J.',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'English',
#     'position': '',
#     'team': {'id': 30,
#      'abbreviation': 'WAS',
#      'city': 'Washington',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Washington Wizards',
#      'name': 'Wizards'},
#     'weight_pounds': None},
#    {'id': 565,
#     'first_name': 'John',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Battle',
#     'position': '',
#     'team': {'id': 1,
#      'abbreviation': 'ATL',
#      'city': 'Atlanta',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Atlanta Hawks',
#      'name': 'Hawks'},
#     'weight_pounds': None},
#    {'id': 566,
#     'first_name': 'Sam',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Vincent',
#     'position': '',
#     'team': {'id': 22,
#      'abbreviation': 'ORL',
#      'city': 'Orlando',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Orlando Magic',
#      'name': 'Magic'},
#     'weight_pounds': None},
#    {'id': 567,
#     'first_name': 'Isiah',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Thomas',
#     'position': '',
#     'team': {'id': 9,
#      'abbreviation': 'DET',
#      'city': 'Detroit',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Detroit Pistons',
#      'name': 'Pistons'},
#     'weight_pounds': None},
#    {'id': 568,
#     'first_name': 'Brad',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Lohaus',
#     'position': '',
#     'team': {'id': 17,
#      'abbreviation': 'MIL',
#      'city': 'Milwaukee',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Milwaukee Bucks',
#      'name': 'Bucks'},
#     'weight_pounds': None},
#    {'id': 569,
#     'first_name': 'Mike',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Brown',
#     'position': '',
#     'team': {'id': 29,
#      'abbreviation': 'UTA',
#      'city': 'Utah',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Utah Jazz',
#      'name': 'Jazz'},
#     'weight_pounds': None},
#    {'id': 570,
#     'first_name': 'Kenny',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Battle',
#     'position': '',
#     'team': {'id': 24,
#      'abbreviation': 'PHX',
#      'city': 'Phoenix',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Phoenix Suns',
#      'name': 'Suns'},
#     'weight_pounds': None},
#    {'id': 571,
#     'first_name': 'Danny',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Young',
#     'position': '',
#     'team': {'id': 25,
#      'abbreviation': 'POR',
#      'city': 'Portland',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Portland Trail Blazers',
#      'name': 'Trail Blazers'},
#     'weight_pounds': None},
#    {'id': 572,
#     'first_name': 'Larry',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Smith',
#     'position': '',
#     'team': {'id': 11,
#      'abbreviation': 'HOU',
#      'city': 'Houston',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Houston Rockets',
#      'name': 'Rockets'},
#     'weight_pounds': None}],
#   'meta': {'total_pages': 52,
#    'current_page': 1,
#    'next_page': 2,
#    'per_page': 100,
#    'total_count': 5126}},
#  {'data': [{'id': 573,
#     'first_name': 'Pooh',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Richardson',
#     'position': '',
#     'team': {'id': 18,
#      'abbreviation': 'MIN',
#      'city': 'Minnesota',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Minnesota Timberwolves',
#      'name': 'Timberwolves'},
#     'weight_pounds': None},
#    {'id': 574,
#     'first_name': 'Derek',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Harper',
#     'position': '',
#     'team': {'id': 7,
#      'abbreviation': 'DAL',
#      'city': 'Dallas',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Dallas Mavericks',
#      'name': 'Mavericks'},
#     'weight_pounds': None},
#    {'id': 575,
#     'first_name': 'Michael',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Adams',
#     'position': '',
#     'team': {'id': 8,
#      'abbreviation': 'DEN',
#      'city': 'Denver',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Denver Nuggets',
#      'name': 'Nuggets'},
#     'weight_pounds': None},
#    {'id': 576,
#     'first_name': 'Tim',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Hardaway',
#     'position': '',
#     'team': {'id': 10,
#      'abbreviation': 'GSW',
#      'city': 'Golden State',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Golden State Warriors',
#      'name': 'Warriors'},
#     'weight_pounds': None},
#    {'id': 577,
#     'first_name': 'Bimbo',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Coles',
#     'position': '',
#     'team': {'id': 16,
#      'abbreviation': 'MIA',
#      'city': 'Miami',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Miami Heat',
#      'name': 'Heat'},
#     'weight_pounds': None},
#    {'id': 578,
#     'first_name': 'Darrell',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Walker',
#     'position': '',
#     'team': {'id': 30,
#      'abbreviation': 'WAS',
#      'city': 'Washington',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Washington Wizards',
#      'name': 'Wizards'},
#     'weight_pounds': None},
#    {'id': 579,
#     'first_name': 'Kevin',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Willis',
#     'position': '',
#     'team': {'id': 1,
#      'abbreviation': 'ATL',
#      'city': 'Atlanta',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Atlanta Hawks',
#      'name': 'Hawks'},
#     'weight_pounds': None},
#    {'id': 580,
#     'first_name': 'Otis',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Smith',
#     'position': '',
#     'team': {'id': 22,
#      'abbreviation': 'ORL',
#      'city': 'Orlando',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Orlando Magic',
#      'name': 'Magic'},
#     'weight_pounds': None},
#    {'id': 581,
#     'first_name': 'James',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Edwards',
#     'position': '',
#     'team': {'id': 9,
#      'abbreviation': 'DET',
#      'city': 'Detroit',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Detroit Pistons',
#      'name': 'Pistons'},
#     'weight_pounds': None},
#    {'id': 582,
#     'first_name': 'Frank',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Brickowski',
#     'position': '',
#     'team': {'id': 17,
#      'abbreviation': 'MIL',
#      'city': 'Milwaukee',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Milwaukee Bucks',
#      'name': 'Bucks'},
#     'weight_pounds': None},
#    {'id': 583,
#     'first_name': 'Karl',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Malone',
#     'position': '',
#     'team': {'id': 29,
#      'abbreviation': 'UTA',
#      'city': 'Utah',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Utah Jazz',
#      'name': 'Jazz'},
#     'weight_pounds': None},
#    {'id': 584,
#     'first_name': 'Ian',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Lockhart',
#     'position': '',
#     'team': {'id': 24,
#      'abbreviation': 'PHX',
#      'city': 'Phoenix',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Phoenix Suns',
#      'name': 'Suns'},
#     'weight_pounds': None},
#    {'id': 585,
#     'first_name': 'Kevin',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Duckworth',
#     'position': '',
#     'team': {'id': 25,
#      'abbreviation': 'POR',
#      'city': 'Portland',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Portland Trail Blazers',
#      'name': 'Trail Blazers'},
#     'weight_pounds': None},
#    {'id': 586,
#     'first_name': 'Otis',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Thorpe',
#     'position': '',
#     'team': {'id': 11,
#      'abbreviation': 'HOU',
#      'city': 'Houston',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Houston Rockets',
#      'name': 'Rockets'},
#     'weight_pounds': None},
#    {'id': 587,
#     'first_name': 'Gerald',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Glass',
#     'position': '',
#     'team': {'id': 18,
#      'abbreviation': 'MIN',
#      'city': 'Minnesota',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Minnesota Timberwolves',
#      'name': 'Timberwolves'},
#     'weight_pounds': None},
#    {'id': 588,
#     'first_name': 'Alex',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'English',
#     'position': '',
#     'team': {'id': 7,
#      'abbreviation': 'DAL',
#      'city': 'Dallas',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Dallas Mavericks',
#      'name': 'Mavericks'},
#     'weight_pounds': None},
#    {'id': 589,
#     'first_name': 'T.R.',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Dunn',
#     'position': '',
#     'team': {'id': 8,
#      'abbreviation': 'DEN',
#      'city': 'Denver',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Denver Nuggets',
#      'name': 'Nuggets'},
#     'weight_pounds': None},
#    {'id': 590,
#     'first_name': 'Alton',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Lister',
#     'position': '',
#     'team': {'id': 10,
#      'abbreviation': 'GSW',
#      'city': 'Golden State',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Golden State Warriors',
#      'name': 'Warriors'},
#     'weight_pounds': None},
#    {'id': 591,
#     'first_name': 'Sherman',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Douglas',
#     'position': '',
#     'team': {'id': 16,
#      'abbreviation': 'MIA',
#      'city': 'Miami',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Miami Heat',
#      'name': 'Heat'},
#     'weight_pounds': None},
#    {'id': 592,
#     'first_name': 'Charles',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Jones',
#     'position': '',
#     'team': {'id': 30,
#      'abbreviation': 'WAS',
#      'city': 'Washington',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Washington Wizards',
#      'name': 'Wizards'},
#     'weight_pounds': None},
#    {'id': 593,
#     'first_name': 'Moses',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Malone',
#     'position': '',
#     'team': {'id': 1,
#      'abbreviation': 'ATL',
#      'city': 'Atlanta',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Atlanta Hawks',
#      'name': 'Hawks'},
#     'weight_pounds': None},
#    {'id': 594,
#     'first_name': 'Mark',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Acres',
#     'position': '',
#     'team': {'id': 22,
#      'abbreviation': 'ORL',
#      'city': 'Orlando',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Orlando Magic',
#      'name': 'Magic'},
#     'weight_pounds': None},
#    {'id': 595,
#     'first_name': 'Lance',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Blanks',
#     'position': '',
#     'team': {'id': 9,
#      'abbreviation': 'DET',
#      'city': 'Detroit',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Detroit Pistons',
#      'name': 'Pistons'},
#     'weight_pounds': None},
#    {'id': 596,
#     'first_name': 'Jeff',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Grayer',
#     'position': '',
#     'team': {'id': 17,
#      'abbreviation': 'MIL',
#      'city': 'Milwaukee',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Milwaukee Bucks',
#      'name': 'Bucks'},
#     'weight_pounds': None},
#    {'id': 597,
#     'first_name': 'Chris',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Munk',
#     'position': '',
#     'team': {'id': 29,
#      'abbreviation': 'UTA',
#      'city': 'Utah',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Utah Jazz',
#      'name': 'Jazz'},
#     'weight_pounds': None},
#    {'id': 598,
#     'first_name': 'Jeff',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Hornacek',
#     'position': '',
#     'team': {'id': 24,
#      'abbreviation': 'PHX',
#      'city': 'Phoenix',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Phoenix Suns',
#      'name': 'Suns'},
#     'weight_pounds': None},
#    {'id': 599,
#     'first_name': 'Jerome',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Kersey',
#     'position': '',
#     'team': {'id': 25,
#      'abbreviation': 'POR',
#      'city': 'Portland',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Portland Trail Blazers',
#      'name': 'Trail Blazers'},
#     'weight_pounds': None},
#    {'id': 600,
#     'first_name': 'Dave',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Feitl',
#     'position': '',
#     'team': {'id': 11,
#      'abbreviation': 'HOU',
#      'city': 'Houston',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Houston Rockets',
#      'name': 'Rockets'},
#     'weight_pounds': None},
#    {'id': 601,
#     'first_name': 'Tod',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Murphy',
#     'position': '',
#     'team': {'id': 18,
#      'abbreviation': 'MIN',
#      'city': 'Minnesota',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Minnesota Timberwolves',
#      'name': 'Timberwolves'},
#     'weight_pounds': None},
#    {'id': 602,
#     'first_name': 'Lafayette',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Lever',
#     'position': '',
#     'team': {'id': 7,
#      'abbreviation': 'DAL',
#      'city': 'Dallas',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Dallas Mavericks',
#      'name': 'Mavericks'},
#     'weight_pounds': None},
#    {'id': 603,
#     'first_name': 'Corey',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Gaines',
#     'position': '',
#     'team': {'id': 8,
#      'abbreviation': 'DEN',
#      'city': 'Denver',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Denver Nuggets',
#      'name': 'Nuggets'},
#     'weight_pounds': None},
#    {'id': 604,
#     'first_name': 'Mitch',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Richmond',
#     'position': '',
#     'team': {'id': 10,
#      'abbreviation': 'GSW',
#      'city': 'Golden State',
#      'conference': 'West',
#      'division': 'Pacific',
# ...
#     'team': {'id': 29,
#      'abbreviation': 'UTA',
#      'city': 'Utah',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Utah Jazz',
#      'name': 'Jazz'},
#     'weight_pounds': None},
#    {'id': 630,
#     'first_name': 'Thurl',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Bailey',
#     'position': '',
#     'team': {'id': 29,
#      'abbreviation': 'UTA',
#      'city': 'Utah',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Utah Jazz',
#      'name': 'Jazz'},
#     'weight_pounds': None},
#    {'id': 631,
#     'first_name': 'Kurt',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Rambis',
#     'position': '',
#     'team': {'id': 24,
#      'abbreviation': 'PHX',
#      'city': 'Phoenix',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Phoenix Suns',
#      'name': 'Suns'},
#     'weight_pounds': None},
#    {'id': 632,
#     'first_name': 'Clyde',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Drexler',
#     'position': '',
#     'team': {'id': 25,
#      'abbreviation': 'POR',
#      'city': 'Portland',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Portland Trail Blazers',
#      'name': 'Trail Blazers'},
#     'weight_pounds': None},
#    {'id': 633,
#     'first_name': 'David',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Wood',
#     'position': '',
#     'team': {'id': 11,
#      'abbreviation': 'HOU',
#      'city': 'Houston',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Houston Rockets',
#      'name': 'Rockets'},
#     'weight_pounds': None},
#    {'id': 634,
#     'first_name': 'Sam',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Mitchell',
#     'position': '',
#     'team': {'id': 18,
#      'abbreviation': 'MIN',
#      'city': 'Minnesota',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Minnesota Timberwolves',
#      'name': 'Timberwolves'},
#     'weight_pounds': None},
#    {'id': 635,
#     'first_name': 'Rodney',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'McCray',
#     'position': '',
#     'team': {'id': 7,
#      'abbreviation': 'DAL',
#      'city': 'Dallas',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Dallas Mavericks',
#      'name': 'Mavericks'},
#     'weight_pounds': None},
#    {'id': 636,
#     'first_name': 'Blair',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Rasmussen',
#     'position': '',
#     'team': {'id': 8,
#      'abbreviation': 'DEN',
#      'city': 'Denver',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Denver Nuggets',
#      'name': 'Nuggets'},
#     'weight_pounds': None},
#    {'id': 637,
#     'first_name': 'Kevin',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Pritchard',
#     'position': '',
#     'team': {'id': 10,
#      'abbreviation': 'GSW',
#      'city': 'Golden State',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Golden State Warriors',
#      'name': 'Warriors'},
#     'weight_pounds': None},
#    {'id': 638,
#     'first_name': 'Milt',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Wagner',
#     'position': '',
#     'team': {'id': 16,
#      'abbreviation': 'MIA',
#      'city': 'Miami',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Miami Heat',
#      'name': 'Heat'},
#     'weight_pounds': None},
#    {'id': 639,
#     'first_name': 'Bernard',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'King',
#     'position': '',
#     'team': {'id': 30,
#      'abbreviation': 'WAS',
#      'city': 'Washington',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Washington Wizards',
#      'name': 'Wizards'},
#     'weight_pounds': None},
#    {'id': 640,
#     'first_name': 'Roy',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Hinson',
#     'position': '',
#     'team': {'id': 3,
#      'abbreviation': 'BKN',
#      'city': 'Brooklyn',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Brooklyn Nets',
#      'name': 'Nets'},
#     'weight_pounds': None},
#    {'id': 641,
#     'first_name': 'Matt',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Bullard',
#     'position': '',
#     'team': {'id': 11,
#      'abbreviation': 'HOU',
#      'city': 'Houston',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Houston Rockets',
#      'name': 'Rockets'},
#     'weight_pounds': None},
#    {'id': 642,
#     'first_name': 'Alan',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Ogg',
#     'position': '',
#     'team': {'id': 16,
#      'abbreviation': 'MIA',
#      'city': 'Miami',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Miami Heat',
#      'name': 'Heat'},
#     'weight_pounds': None},
#    {'id': 643,
#     'first_name': 'Kevin',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Lynch',
#     'position': '',
#     'team': {'id': 4,
#      'abbreviation': 'CHA',
#      'city': 'Charlotte',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Charlotte Hornets',
#      'name': 'Hornets'},
#     'weight_pounds': None},
#    {'id': 644,
#     'first_name': 'Larry',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Krystkowiak',
#     'position': '',
#     'team': {'id': 17,
#      'abbreviation': 'MIL',
#      'city': 'Milwaukee',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Milwaukee Bucks',
#      'name': 'Bucks'},
#     'weight_pounds': None},
#    {'id': 645,
#     'first_name': 'Pete',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Chilcutt',
#     'position': '',
#     'team': {'id': 26,
#      'abbreviation': 'SAC',
#      'city': 'Sacramento',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Sacramento Kings',
#      'name': 'Kings'},
#     'weight_pounds': None},
#    {'id': 646,
#     'first_name': 'Randy',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Brown',
#     'position': '',
#     'team': {'id': 26,
#      'abbreviation': 'SAC',
#      'city': 'Sacramento',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Sacramento Kings',
#      'name': 'Kings'},
#     'weight_pounds': None},
#    {'id': 647,
#     'first_name': 'Elliot',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Perry',
#     'position': '',
#     'team': {'id': 13,
#      'abbreviation': 'LAC',
#      'city': 'LA',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'LA Clippers',
#      'name': 'Clippers'},
#     'weight_pounds': None},
#    {'id': 648,
#     'first_name': 'Jimmy',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Oliver',
#     'position': '',
#     'team': {'id': 6,
#      'abbreviation': 'CLE',
#      'city': 'Cleveland',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Cleveland Cavaliers',
#      'name': 'Cavaliers'},
#     'weight_pounds': None},
#    {'id': 649,
#     'first_name': 'Terrell',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Brandon',
#     'position': '',
#     'team': {'id': 6,
#      'abbreviation': 'CLE',
#      'city': 'Cleveland',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Cleveland Cavaliers',
#      'name': 'Cavaliers'},
#     'weight_pounds': None},
#    {'id': 650,
#     'first_name': 'Greg',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Sutton',
#     'position': '',
#     'team': {'id': 27,
#      'abbreviation': 'SAS',
#      'city': 'San Antonio',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'San Antonio Spurs',
#      'name': 'Spurs'},
#     'weight_pounds': None},
#    {'id': 651,
#     'first_name': 'Tom',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Copa',
#     'position': '',
#     'team': {'id': 27,
#      'abbreviation': 'SAS',
#      'city': 'San Antonio',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'San Antonio Spurs',
#      'name': 'Spurs'},
#     'weight_pounds': None},
#    {'id': 652,
#     'first_name': 'Donald',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Hodge',
#     'position': '',
#     'team': {'id': 7,
#      'abbreviation': 'DAL',
#      'city': 'Dallas',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Dallas Mavericks',
#      'name': 'Mavericks'},
#     'weight_pounds': None},
#    {'id': 653,
#     'first_name': 'Joao',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Vianna',
#     'position': '',
#     'team': {'id': 7,
#      'abbreviation': 'DAL',
#      'city': 'Dallas',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Dallas Mavericks',
#      'name': 'Mavericks'},
#     'weight_pounds': None},
#    {'id': 654,
#     'first_name': 'Mike',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Iuzzolino',
#     'position': '',
#     'team': {'id': 7,
#      'abbreviation': 'DAL',
#      'city': 'Dallas',
#      'conference': 'West',
#      'division': 'Southwest',
#      'full_name': 'Dallas Mavericks',
#      'name': 'Mavericks'},
#     'weight_pounds': None},
#    {'id': 655,
#     'first_name': 'Greg',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Anthony',
#     'position': '',
#     'team': {'id': 20,
#      'abbreviation': 'NYK',
#      'city': 'New York',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'New York Knicks',
#      'name': 'Knicks'},
#     'weight_pounds': None},
#    {'id': 656,
#     'first_name': 'Albert',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'King',
#     'position': '',
#     'team': {'id': 30,
#      'abbreviation': 'WAS',
#      'city': 'Washington',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Washington Wizards',
#      'name': 'Wizards'},
#     'weight_pounds': None},
#    {'id': 657,
#     'first_name': 'Tellis',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Frank',
#     'position': '',
#     'team': {'id': 18,
#      'abbreviation': 'MIN',
#      'city': 'Minnesota',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Minnesota Timberwolves',
#      'name': 'Timberwolves'},
#     'weight_pounds': None},
#    {'id': 658,
#     'first_name': 'David',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Benoit',
#     'position': '',
#     'team': {'id': 29,
#      'abbreviation': 'UTA',
#      'city': 'Utah',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Utah Jazz',
#      'name': 'Jazz'},
#     'weight_pounds': None},
#    {'id': 659,
#     'first_name': 'Demetrius',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Calip',
#     'position': '',
#     'team': {'id': 14,
#      'abbreviation': 'LAL',
#      'city': 'Los Angeles',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Los Angeles Lakers',
#      'name': 'Lakers'},
#     'weight_pounds': None},
#    {'id': 660,
#     'first_name': 'Dikembe',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Mutombo',
#     'position': '',
#     'team': {'id': 8,
#      'abbreviation': 'DEN',
#      'city': 'Denver',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Denver Nuggets',
#      'name': 'Nuggets'},
#     'weight_pounds': None},
#    {'id': 661,
#     'first_name': 'Mark',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Macon',
#     'position': '',
#     'team': {'id': 8,
#      'abbreviation': 'DEN',
#      'city': 'Denver',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Denver Nuggets',
#      'name': 'Nuggets'},
#     'weight_pounds': None},
#    {'id': 662,
#     'first_name': 'Chris',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Gatling',
#     'position': '',
#     'team': {'id': 10,
#      'abbreviation': 'GSW',
#      'city': 'Golden State',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Golden State Warriors',
#      'name': 'Warriors'},
#     'weight_pounds': None},
#    {'id': 663,
#     'first_name': 'Victor',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Alexander',
#     'position': '',
#     'team': {'id': 10,
#      'abbreviation': 'GSW',
#      'city': 'Golden State',
#      'conference': 'West',
#      'division': 'Pacific',
#      'full_name': 'Golden State Warriors',
#      'name': 'Warriors'},
#     'weight_pounds': None},
#    {'id': 664,
#     'first_name': 'Mark',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Randall',
#     'position': '',
#     'team': {'id': 5,
#      'abbreviation': 'CHI',
#      'city': 'Chicago',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Chicago Bulls',
#      'name': 'Bulls'},
#     'weight_pounds': None},
#    {'id': 665,
#     'first_name': 'Mitchell',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Wiggins',
#     'position': '',
#     'team': {'id': 23,
#      'abbreviation': 'PHI',
#      'city': 'Philadelphia',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Philadelphia 76ers',
#      'name': '76ers'},
#     'weight_pounds': None},
#    {'id': 666,
#     'first_name': 'Tharon',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Mayes',
#     'position': '',
#     'team': {'id': 23,
#      'abbreviation': 'PHI',
#      'city': 'Philadelphia',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Philadelphia 76ers',
#      'name': '76ers'},
#     'weight_pounds': None},
#    {'id': 667,
#     'first_name': 'Charles',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Thomas',
#     'position': '',
#     'team': {'id': 9,
#      'abbreviation': 'DET',
#      'city': 'Detroit',
#      'conference': 'East',
#      'division': 'Central',
#      'full_name': 'Detroit Pistons',
#      'name': 'Pistons'},
#     'weight_pounds': None},
#    {'id': 668,
#     'first_name': 'Robert',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Pack',
#     'position': '',
#     'team': {'id': 25,
#      'abbreviation': 'POR',
#      'city': 'Portland',
#      'conference': 'West',
#      'division': 'Northwest',
#      'full_name': 'Portland Trail Blazers',
#      'name': 'Trail Blazers'},
#     'weight_pounds': None},
#    {'id': 669,
#     'first_name': 'John',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Bagley',
#     'position': '',
#     'team': {'id': 2,
#      'abbreviation': 'BOS',
#      'city': 'Boston',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Boston Celtics',
#      'name': 'Celtics'},
#     'weight_pounds': None},
#    {'id': 670,
#     'first_name': 'Rick',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Fox',
#     'position': '',
#     'team': {'id': 2,
#      'abbreviation': 'BOS',
#      'city': 'Boston',
#      'conference': 'East',
#      'division': 'Atlantic',
#      'full_name': 'Boston Celtics',
#      'name': 'Celtics'},
#     'weight_pounds': None},
#    {'id': 671,
#     'first_name': 'Larry',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Johnson',
#     'position': '',
#     'team': {'id': 4,
#      'abbreviation': 'CHA',
#      'city': 'Charlotte',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Charlotte Hornets',
#      'name': 'Hornets'},
#     'weight_pounds': None},
#    {'id': 672,
#     'first_name': 'Alexander',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'Volkov',
#     'position': '',
#     'team': {'id': 1,
#      'abbreviation': 'ATL',
#      'city': 'Atlanta',
#      'conference': 'East',
#      'division': 'Southeast',
#      'full_name': 'Atlanta Hawks',
#      'name': 'Hawks'},
#     'weight_pounds': None}],
#   'meta': {'total_pages': 52,
#    'current_page': 2,
#    'next_page': 3,
#    'per_page': 100,
#    'total_count': 5126}}]

# %%
all_players = write_json_file(players,"notebooks/players")

# %%
print(all_players)
# Out:
# ('Se ha creado el archivo:', 'notebooks/players.json')

# %%
len(all_players)
# Out:
# 2
